# %% [markdown]
# # PubMed Extraction
#
# Extract desired data from pubmed XML files into csv files to be used in NLP.

# %%
from xml.etree import ElementTree as etree
from pathlib import Path
import gzip, csv
from fastai.text import *

# %%
path = Path("./data") # you probably want a symlink here to your data drive
dest = Path(".")      # for faster speed if not SSD-drive, set dest to a different drive (to avoid head move madness)
#dest = path

# %% [markdown]
# ## Download data

# %%
# run once to download the pubmed data 
# info: 1200+ xml.gz files totalling ~35GB compressed (2019-05)
if 0:
    ! wget -m -np -nd ftp://ftp.ncbi.nlm.nih.gov/pubmed/baseline/    -P {path}
    ! wget -m -np -nd ftp://ftp.ncbi.nlm.nih.gov/pubmed/updatefiles/ -P {path}

# %%
path.ls()
# Out:
# [PosixPath('data/pubmed19n1125_stats.html'),
#  PosixPath('data/pubmed19n0243.xml.gz.md5'),
#  PosixPath('data/pubmed19n1048_stats.html'),
#  PosixPath('data/pubmed19n0257.xml.gz.md5'),
#  PosixPath('data/pubmed19n0378.xml.gz'),
#  PosixPath('data/pubmed19n0961.xml.gz.md5'),
#  PosixPath('data/pubmed19n0381.xml.gz.md5'),
#  PosixPath('data/pubmed19n1065.xml.gz'),
#  PosixPath('data/pubmed19n1002.xml.gz.md5'),
#  PosixPath('data/pubmed19n1204.xml.gz'),
#  PosixPath('data/pubmed19n1154.xml.gz'),
#  PosixPath('data/pubmed19n0997_stats.html'),
#  PosixPath('data/pubmed19n0447.xml.gz.md5'),
#  PosixPath('data/pubmed19n0322.xml.gz'),
#  PosixPath('data/pubmed19n0880.xml.gz.md5'),
#  PosixPath('data/pubmed19n1099_stats.html'),
#  PosixPath('data/pubmed19n0599.xml.gz'),
#  PosixPath('data/pubmed19n0293.xml.gz'),
#  PosixPath('data/pubmed19n0081.xml.gz'),
#  PosixPath('data/pubmed19n1065_stats.html'),
#  PosixPath('data/pubmed19n1108_stats.html'),
#  PosixPath('data/pubmed19n0581.xml.gz'),
#  PosixPath('data/pubmed19n0455.xml.gz'),
#  PosixPath('data/pubmed19n0309.xml.gz'),
#  PosixPath('data/pubmed19n0099.xml.gz.md5'),
#  PosixPath('data/pubmed19n0865.xml.gz.md5'),
#  PosixPath('data/pubmed19n1019.xml.gz.md5'),
#  PosixPath('data/pubmed19n0999.xml.gz'),
#  PosixPath('data/pubmed19n0522.xml.gz.md5'),
#  PosixPath('data/pubmed19n0599.xml.gz.md5'),
#  PosixPath('data/pubmed19n0402.xml.gz'),
#  PosixPath('data/pubmed19n0300.xml.gz.md5'),
#  PosixPath('data/pubmed19n0659.xml.gz'),
#  PosixPath('data/pubmed19n0821.xml.gz.md5'),
#  PosixPath('data/pubmed19n1178.xml.gz'),
#  PosixPath('data/pubmed19n0549.xml.gz'),
#  PosixPath('data/pubmed19n0103.xml.gz.md5'),
#  PosixPath('data/pubmed19n0639.xml.gz.md5'),
#  PosixPath('data/pubmed19n0460.xml.gz.md5'),
#  PosixPath('data/pubmed19n0382.xml.gz.md5'),
#  PosixPath('data/pubmed19n0478.xml.gz.md5'),
#  PosixPath('data/pubmed19n0346.xml.gz'),
#  PosixPath('data/pubmed19n1001_stats.html'),
#  PosixPath('data/pubmed19n0921.xml.gz'),
#  PosixPath('data/pubmed19n0198.xml.gz'),
#  PosixPath('data/pubmed19n0747.xml.gz'),
#  PosixPath('data/pubmed19n0530.xml.gz'),
#  PosixPath('data/pubmed19n0540.xml.gz'),
#  PosixPath('data/pubmed19n0997.xml.gz'),
#  PosixPath('data/pubmed19n1126_stats.html'),
#  PosixPath('data/pubmed19n1067.xml.gz.md5'),
#  PosixPath('data/pubmed19n0080.xml.gz'),
#  PosixPath('data/pubmed19n0122.xml.gz.md5'),
#  PosixPath('data/pubmed19n0019.xml.gz'),
#  PosixPath('data/pubmed19n0525.xml.gz'),
#  PosixPath('data/pubmed19n0158.xml.gz.md5'),
#  PosixPath('data/pubmed19n0879.xml.gz.md5'),
#  PosixPath('data/pubmed19n0494.xml.gz.md5'),
#  PosixPath('data/pubmed19n0416.xml.gz.md5'),
#  PosixPath('data/pubmed19n1183_stats.html'),
#  PosixPath('data/pubmed19n1119.xml.gz.md5'),
#  PosixPath('data/pubmed19n0728.xml.gz'),
#  PosixPath('data/pubmed19n0541.xml.gz'),
#  PosixPath('data/pubmed19n0270.xml.gz.md5'),
#  PosixPath('data/pubmed19n0923.xml.gz.md5'),
#  PosixPath('data/pubmed19n0785.xml.gz.md5'),
#  PosixPath('data/pubmed19n0007.xml.gz'),
#  PosixPath('data/pubmed19n0503.xml.gz'),
#  PosixPath('data/pubmed19n0669.xml.gz'),
#  PosixPath('data/pubmed19n0389.xml.gz'),
#  PosixPath('data/pubmed19n1011_stats.html'),
#  PosixPath('data/pubmed19n0307.xml.gz'),
#  PosixPath('data/pubmed19n0490.xml.gz.md5'),
#  PosixPath('data/pubmed19n0974.xml.gz'),
#  PosixPath('data/pubmed19n0947.xml.gz'),
#  PosixPath('data/pubmed19n0399.xml.gz'),
#  PosixPath('data/pubmed19n0301.xml.gz'),
#  PosixPath('data/pubmed19n0387.xml.gz'),
#  PosixPath('data/pubmed19n1194.xml.gz'),
#  PosixPath('data/pubmed19n0321.xml.gz.md5'),
#  PosixPath('data/pubmed19n0752.xml.gz.md5'),
#  PosixPath('data/pubmed19n1185.xml.gz.md5'),
#  PosixPath('data/pubmed19n0980.xml.gz'),
#  PosixPath('data/pubmed19n1141_stats.html'),
#  PosixPath('data/pubmed19n0592.xml.gz.md5'),
#  PosixPath('data/pubmed19n0184.xml.gz.md5'),
#  PosixPath('data/pubmed19n0934.xml.gz.md5'),
#  PosixPath('data/pubmed19n1041.xml.gz'),
#  PosixPath('data/pubmed19n0554.xml.gz.md5'),
#  PosixPath('data/pubmed19n0191.xml.gz.md5'),
#  PosixPath('data/pubmed19n0245.xml.gz.md5'),
#  PosixPath('data/pubmed19n0448.xml.gz.md5'),
#  PosixPath('data/pubmed19n0668.xml.gz.md5'),
#  PosixPath('data/pubmed19n1203_stats.html'),
#  PosixPath('data/pubmed19n0304.xml.gz'),
#  PosixPath('data/pubmed19n1145.xml.gz'),
#  PosixPath('data/pubmed19n1177_stats.html'),
#  PosixPath('data/pubmed19n0139.xml.gz'),
#  PosixPath('data/pubmed19n1045.xml.gz'),
#  PosixPath('data/pubmed19n0716.xml.gz.md5'),
#  PosixPath('data/pubmed19n1005.xml.gz'),
#  PosixPath('data/pubmed19n1099.xml.gz'),
#  PosixPath('data/pubmed19n0717.xml.gz.md5'),
#  PosixPath('data/pubmed19n0281.xml.gz'),
#  PosixPath('data/pubmed19n0765.xml.gz.md5'),
#  PosixPath('data/pubmed19n1058.xml.gz.md5'),
#  PosixPath('data/pubmed19n0472.xml.gz.md5'),
#  PosixPath('data/pubmed19n0606.xml.gz.md5'),
#  PosixPath('data/pubmed19n0549.xml.gz.md5'),
#  PosixPath('data/pubmed19n0313.xml.gz.md5'),
#  PosixPath('data/pubmed19n0546.xml.gz.md5'),
#  PosixPath('data/pubmed19n0687.xml.gz'),
#  PosixPath('data/pubmed19n1164_stats.html'),
#  PosixPath('data/pubmed19n1016_stats.html'),
#  PosixPath('data/pubmed19n0353.xml.gz.md5'),
#  PosixPath('data/pubmed19n0857.xml.gz'),
#  PosixPath('data/pubmed19n0608.xml.gz'),
#  PosixPath('data/pubmed19n0919.xml.gz.md5'),
#  PosixPath('data/pubmed19n0924.xml.gz.md5'),
#  PosixPath('data/pubmed19n0060.xml.gz'),
#  PosixPath('data/pubmed19n1086.xml.gz.md5'),
#  PosixPath('data/pubmed19n1136_stats.html'),
#  PosixPath('data/pubmed19n0449.xml.gz'),
#  PosixPath('data/pubmed19n1034.xml.gz.md5'),
#  PosixPath('data/pubmed19n1039.xml.gz'),
#  PosixPath('data/pubmed19n0346.xml.gz.md5'),
#  PosixPath('data/pubmed19n0710.xml.gz'),
#  PosixPath('data/pubmed19n1098_stats.html'),
#  PosixPath('data/pubmed19n0282.xml.gz'),
#  PosixPath('data/pubmed19n0405.xml.gz.md5'),
#  PosixPath('data/pubmed19n0597.xml.gz.md5'),
#  PosixPath('data/pubmed19n1186.xml.gz.md5'),
#  PosixPath('data/pubmed19n0290.xml.gz'),
#  PosixPath('data/pubmed19n0341.xml.gz.md5'),
#  PosixPath('data/pubmed19n1115.xml.gz.md5'),
#  PosixPath('data/pubmed19n0977_stats.html'),
#  PosixPath('data/pubmed19n0671.xml.gz'),
#  PosixPath('data/pubmed19n0224.xml.gz.md5'),
#  PosixPath('data/pubmed19n0672.xml.gz.md5'),
#  PosixPath('data/pubmed19n0417.xml.gz'),
#  PosixPath('data/pubmed19n0703.xml.gz.md5'),
#  PosixPath('data/pubmed19n0911.xml.gz'),
#  PosixPath('data/pubmed19n0379.xml.gz.md5'),
#  PosixPath('data/pubmed19n0274.xml.gz.md5'),
#  PosixPath('data/pubmed19n0053.xml.gz'),
#  PosixPath('data/pubmed19n0937.xml.gz'),
#  PosixPath('data/pubmed19n1065.xml.gz.md5'),
#  PosixPath('data/pubmed19n1091.xml.gz.md5'),
#  PosixPath('data/pubmed19n0419.xml.gz'),
#  PosixPath('data/pubmed19n1026.xml.gz.md5'),
#  PosixPath('data/pubmed19n0049.xml.gz'),
#  PosixPath('data/pubmed19n0812.xml.gz'),
#  PosixPath('data/pubmed19n0987_stats.html'),
#  PosixPath('data/pubmed19n1169.xml.gz.md5'),
#  PosixPath('data/pubmed19n1185_stats.html'),
#  PosixPath('data/pubmed19n1130_stats.html'),
#  PosixPath('data/pubmed19n1135.xml.gz.md5'),
#  PosixPath('data/pubmed19n0197.xml.gz'),
#  PosixPath('data/pubmed19n0165.xml.gz'),
#  PosixPath('data/pubmed19n0998.xml.gz'),
#  PosixPath('data/pubmed19n1103.xml.gz'),
#  PosixPath('data/pubmed19n0274.xml.gz'),
#  PosixPath('data/pubmed19n0613.xml.gz'),
#  PosixPath('data/pubmed19n0401.xml.gz.md5'),
#  PosixPath('data/pubmed19n0788.xml.gz.md5'),
#  PosixPath('data/pubmed19n0914.xml.gz'),
#  PosixPath('data/pubmed19n0155.xml.gz'),
#  PosixPath('data/pubmed19n0929.xml.gz'),
#  PosixPath('data/pubmed19n1191.xml.gz.md5'),
#  PosixPath('data/pubmed19n1096_stats.html'),
#  PosixPath('data/pubmed19n0464.xml.gz'),
#  PosixPath('data/pubmed19n0094.xml.gz'),
#  PosixPath('data/pubmed19n0587.xml.gz'),
#  PosixPath('data/pubmed19n0842.xml.gz.md5'),
#  PosixPath('data/pubmed19n1012.xml.gz.md5'),
#  PosixPath('data/pubmed19n0985.xml.gz.md5'),
#  PosixPath('data/pubmed19n0719.xml.gz'),
#  PosixPath('data/pubmed19n0336.xml.gz.md5'),
#  PosixPath('data/pubmed19n1150.xml.gz'),
#  PosixPath('data/pubmed19n0441.xml.gz'),
#  PosixPath('data/pubmed19n0100.xml.gz.md5'),
#  PosixPath('data/pubmed19n1202_stats.html'),
#  PosixPath('data/pubmed19n0993_stats.html'),
#  PosixPath('data/pubmed19n1131_stats.html'),
#  PosixPath('data/pubmed19n0642.xml.gz'),
#  PosixPath('data/pubmed19n0718.xml.gz'),
#  PosixPath('data/pubmed19n0348.xml.gz.md5'),
#  PosixPath('data/pubmed19n0051.xml.gz'),
#  PosixPath('data/pubmed19n0687.xml.gz.md5'),
#  PosixPath('data/pubmed19n0321.xml.gz'),
#  PosixPath('data/pubmed19n0182.xml.gz.md5'),
#  PosixPath('data/pubmed19n1198_stats.html'),
#  PosixPath('data/pubmed19n0879.xml.gz'),
#  PosixPath('data/pubmed19n1126.xml.gz'),
#  PosixPath('data/pubmed19n0520.xml.gz.md5'),
#  PosixPath('data/pubmed19n1163.xml.gz.md5'),
#  PosixPath('data/pubmed19n1060_stats.html'),
#  PosixPath('data/pubmed19n0576.xml.gz'),
#  PosixPath('data/pubmed19n0497.xml.gz'),
#  PosixPath('data/pubmed19n1027.xml.gz.md5'),
#  PosixPath('data/pubmed19n1131.xml.gz'),
#  PosixPath('data/pubmed19n0609.xml.gz'),
#  PosixPath('data/pubmed19n0228.xml.gz.md5'),
#  PosixPath('data/pubmed19n0818.xml.gz.md5'),
#  PosixPath('data/pubmed19n1177.xml.gz.md5'),
#  PosixPath('data/pubmed19n0840.xml.gz'),
#  PosixPath('data/pubmed19n0250.xml.gz.md5'),
#  PosixPath('data/pubmed19n0922.xml.gz'),
#  PosixPath('data/pubmed19n0257.xml.gz'),
#  PosixPath('data/pubmed19n0830.xml.gz.md5'),
#  PosixPath('data/pubmed19n0788.xml.gz'),
#  PosixPath('data/pubmed19n0470.xml.gz'),
#  PosixPath('data/pubmed19n0660.xml.gz.md5'),
#  PosixPath('data/pubmed19n0334.xml.gz'),
#  PosixPath('data/pubmed19n0575.xml.gz.md5'),
#  PosixPath('data/pubmed19n0707.xml.gz'),
#  PosixPath('data/pubmed19n0284.xml.gz'),
#  PosixPath('data/pubmed19n0712.xml.gz.md5'),
#  PosixPath('data/pubmed19n0636.xml.gz.md5'),
#  PosixPath('data/pubmed19n1200.xml.gz.md5'),
#  PosixPath('data/pubmed19n0656.xml.gz.md5'),
#  PosixPath('data/pubmed19n0733.xml.gz'),
#  PosixPath('data/pubmed19n1088.xml.gz.md5'),
#  PosixPath('data/pubmed19n0510.xml.gz.md5'),
#  PosixPath('data/pubmed19n0675.xml.gz.md5'),
#  PosixPath('data/pubmed19n1020.xml.gz.md5'),
#  PosixPath('data/pubmed19n0652.xml.gz.md5'),
#  PosixPath('data/pubmed19n0007.xml.gz.md5'),
#  PosixPath('data/pubmed19n0997.xml.gz.md5'),
#  PosixPath('data/pubmed19n0163.xml.gz.md5'),
#  PosixPath('data/pubmed19n0781.xml.gz.md5'),
#  PosixPath('data/pubmed19n0515.xml.gz.md5'),
#  PosixPath('data/pubmed19n1014.xml.gz.md5'),
#  PosixPath('data/pubmed19n0810.xml.gz'),
#  PosixPath('data/pubmed19n0755.xml.gz'),
#  PosixPath('data/pubmed19n0376.xml.gz.md5'),
#  PosixPath('data/pubmed19n1070_stats.html'),
#  PosixPath('data/pubmed19n0806.xml.gz'),
#  PosixPath('data/pubmed19n0799.xml.gz.md5'),
#  PosixPath('data/pubmed19n0713.xml.gz.md5'),
#  PosixPath('data/pubmed19n1005.xml.gz.md5'),
#  PosixPath('data/pubmed19n0499.xml.gz.md5'),
#  PosixPath('data/pubmed19n0681.xml.gz'),
#  PosixPath('data/pubmed19n0030.xml.gz.md5'),
#  PosixPath('data/pubmed19n1192.xml.gz.md5'),
#  PosixPath('data/pubmed19n0797.xml.gz'),
#  PosixPath('data/pubmed19n0265.xml.gz.md5'),
#  PosixPath('data/pubmed19n0917.xml.gz'),
#  PosixPath('data/pubmed19n0647.xml.gz.md5'),
#  PosixPath('data/pubmed19n1083.xml.gz.md5'),
#  PosixPath('data/pubmed19n0652.xml.gz'),
#  PosixPath('data/pubmed19n0688.xml.gz'),
#  PosixPath('data/pubmed19n0817.xml.gz.md5'),
#  PosixPath('data/pubmed19n0511.xml.gz.md5'),
#  PosixPath('data/pubmed19n0678.xml.gz'),
#  PosixPath('data/README.txt'),
#  PosixPath('data/pubmed19n0964.xml.gz.md5'),
#  PosixPath('data/pubmed19n0625.xml.gz'),
#  PosixPath('data/pubmed19n0275.xml.gz.md5'),
#  PosixPath('data/pubmed19n0694.xml.gz'),
#  PosixPath('data/pubmed19n0462.xml.gz.md5'),
#  PosixPath('data/pubmed19n0426.xml.gz'),
#  PosixPath('data/pubmed19n0598.xml.gz.md5'),
#  PosixPath('data/pubmed19n1104.xml.gz'),
#  PosixPath('data/pubmed19n0750.xml.gz'),
#  PosixPath('data/pubmed19n0627.xml.gz.md5'),
#  PosixPath('data/pubmed19n0721.xml.gz.md5'),
#  PosixPath('data/pubmed19n1093_stats.html'),
#  PosixPath('data/pubmed19n0664.xml.gz.md5'),
#  PosixPath('data/pubmed19n0576.xml.gz.md5'),
#  PosixPath('data/pubmed19n0573.xml.gz.md5'),
#  PosixPath('data/pubmed19n0471.xml.gz.md5'),
#  PosixPath('data/pubmed19n0356.xml.gz.md5'),
#  PosixPath('data/pubmed19n0654.xml.gz'),
#  PosixPath('data/pubmed19n1036.xml.gz.md5'),
#  PosixPath('data/pubmed19n0151.xml.gz.md5'),
#  PosixPath('data/pubmed19n0977.xml.gz'),
#  PosixPath('data/pubmed19n0908.xml.gz.md5'),
#  PosixPath('data/pubmed19n0633.xml.gz.md5'),
#  PosixPath('data/pubmed19n0839.xml.gz.md5'),
#  PosixPath('data/pubmed19n1158.xml.gz'),
#  PosixPath('data/pubmed19n0858.xml.gz'),
#  PosixPath('data/pubmed19n0866.xml.gz.md5'),
#  PosixPath('data/pubmed19n0815.xml.gz'),
#  PosixPath('data/pubmed19n0333.xml.gz'),
#  PosixPath('data/pubmed19n0543.xml.gz.md5'),
#  PosixPath('data/pubmed19n1147.xml.gz.md5'),
#  PosixPath('data/pubmed19n0991_stats.html'),
#  PosixPath('data/pubmed19n1124_stats.html'),
#  PosixPath('data/pubmed19n0223.xml.gz'),
#  PosixPath('data/pubmed19n0035.xml.gz.md5'),
#  PosixPath('data/pubmed19n0344.xml.gz'),
#  PosixPath('data/pubmed19n0342.xml.gz.md5'),
#  PosixPath('data/pubmed19n1194.xml.gz.md5'),
#  PosixPath('data/pubmed19n1089.xml.gz'),
#  PosixPath('data/pubmed19n1046.xml.gz'),
#  PosixPath('data/pubmed19n0522.xml.gz'),
#  PosixPath('data/pubmed19n1128.xml.gz.md5'),
#  PosixPath('data/pubmed19n0467.xml.gz'),
#  PosixPath('data/pubmed19n0711.xml.gz.md5'),
#  PosixPath('data/pubmed19n0754.xml.gz.md5'),
#  PosixPath('data/pubmed19n1076.xml.gz.md5'),
#  PosixPath('data/pubmed19n0988.xml.gz.md5'),
#  PosixPath('data/pubmed19n1075.xml.gz'),
#  PosixPath('data/pubmed19n0330.xml.gz.md5'),
#  PosixPath('data/pubmed19n0887.xml.gz'),
#  PosixPath('data/pubmed19n0249.xml.gz.md5'),
#  PosixPath('data/pubmed19n0870.xml.gz.md5'),
#  PosixPath('data/pubmed19n1085.xml.gz'),
#  PosixPath('data/pubmed19n0981.xml.gz'),
#  PosixPath('data/pubmed19n0501.xml.gz.md5'),
#  PosixPath('data/pubmed19n0740.xml.gz'),
#  PosixPath('data/pubmed19n1163.xml.gz'),
#  PosixPath('data/pubmed19n0065.xml.gz'),
#  PosixPath('data/pubmed19n0259.xml.gz'),
#  PosixPath('data/pubmed19n0878.xml.gz'),
#  PosixPath('data/pubmed19n1167_stats.html'),
#  PosixPath('data/pubmed19n0750.xml.gz.md5'),
#  PosixPath('data/pubmed19n0550.xml.gz'),
#  PosixPath('data/pubmed19n0022.xml.gz'),
#  PosixPath('data/pubmed19n0758.xml.gz'),
#  PosixPath('data/pubmed19n0383.xml.gz'),
#  PosixPath('data/pubmed19n1050.xml.gz.md5'),
#  PosixPath('data/pubmed19n1112.xml.gz'),
#  PosixPath('data/pubmed19n0292.xml.gz'),
#  PosixPath('data/pubmed19n1203.xml.gz.md5'),
#  PosixPath('data/pubmed19n0418.xml.gz.md5'),
#  PosixPath('data/pubmed19n0352.xml.gz.md5'),
#  PosixPath('data/pubmed19n0746.xml.gz'),
#  PosixPath('data/pubmed19n0166.xml.gz.md5'),
#  PosixPath('data/pubmed19n0328.xml.gz'),
#  PosixPath('data/pubmed19n0676.xml.gz.md5'),
#  PosixPath('data/pubmed19n0730.xml.gz.md5'),
#  PosixPath('data/pubmed19n0392.xml.gz'),
#  PosixPath('data/pubmed19n1157.xml.gz.md5'),
#  PosixPath('data/pubmed19n0280.xml.gz.md5'),
#  PosixPath('data/pubmed19n0467.xml.gz.md5'),
#  PosixPath('data/pubmed19n0371.xml.gz.md5'),
#  PosixPath('data/pubmed19n0922.xml.gz.md5'),
#  PosixPath('data/pubmed19n0369.xml.gz.md5'),
#  PosixPath('data/pubmed19n0759.xml.gz'),
#  PosixPath('data/pubmed19n1014.xml.gz'),
#  PosixPath('data/pubmed19n1181_stats.html'),
#  PosixPath('data/pubmed19n0666.xml.gz'),
#  PosixPath('data/pubmed19n1032_stats.html'),
#  PosixPath('data/pubmed19n0627.xml.gz'),
#  PosixPath('data/pubmed19n1098.xml.gz'),
#  PosixPath('data/pubmed19n0806.xml.gz.md5'),
#  PosixPath('data/pubmed19n0695.xml.gz.md5'),
#  PosixPath('data/pubmed19n0516.xml.gz.md5'),
#  PosixPath('data/pubmed19n0939.xml.gz'),
#  PosixPath('data/pubmed19n0050.xml.gz'),
#  PosixPath('data/pubmed19n0906.xml.gz'),
#  PosixPath('data/pubmed19n1090_stats.html'),
#  PosixPath('data/pubmed19n1117.xml.gz'),
#  PosixPath('data/pubmed19n0731.xml.gz'),
#  PosixPath('data/pubmed19n0572.xml.gz'),
#  PosixPath('data/pubmed19n0784.xml.gz'),
#  PosixPath('data/pubmed19n0751.xml.gz'),
#  PosixPath('data/pubmed19n0773.xml.gz.md5'),
#  PosixPath('data/pubmed19n0097.xml.gz'),
#  PosixPath('data/pubmed19n0615.xml.gz.md5'),
#  PosixPath('data/pubmed19n0094.xml.gz.md5'),
#  PosixPath('data/pubmed19n0653.xml.gz.md5'),
#  PosixPath('data/pubmed19n0957.xml.gz.md5'),
#  PosixPath('data/pubmed19n1150.xml.gz.md5'),
#  PosixPath('data/pubmed19n0367.xml.gz'),
#  PosixPath('data/pubmed19n0805.xml.gz'),
#  PosixPath('data/pubmed19n0218.xml.gz.md5'),
#  PosixPath('data/pubmed19n0167.xml.gz.md5'),
#  PosixPath('data/pubmed19n0603.xml.gz'),
#  PosixPath('data/pubmed19n0208.xml.gz'),
#  PosixPath('data/pubmed19n0043.xml.gz.md5'),
#  PosixPath('data/pubmed19n1063_stats.html'),
#  PosixPath('data/pubmed19n0359.xml.gz.md5'),
#  PosixPath('data/pubmed19n0149.xml.gz.md5'),
#  PosixPath('data/pubmed19n1036.xml.gz'),
#  PosixPath('data/pubmed19n0126.xml.gz'),
#  PosixPath('data/pubmed19n1140.xml.gz.md5'),
#  PosixPath('data/pubmed19n0798.xml.gz'),
#  PosixPath('data/pubmed19n1023_stats.html'),
#  PosixPath('data/pubmed19n0153.xml.gz.md5'),
#  PosixPath('data/pubmed19n0807.xml.gz.md5'),
#  PosixPath('data/pubmed19n1197.xml.gz'),
#  PosixPath('data/pubmed19n0720.xml.gz.md5'),
#  PosixPath('data/pubmed19n1110.xml.gz.md5'),
#  PosixPath('data/pubmed19n1121.xml.gz'),
#  PosixPath('data/pubmed19n1114_stats.html'),
#  PosixPath('data/pubmed19n0525.xml.gz.md5'),
#  PosixPath('data/pubmed19n0935.xml.gz.md5'),
#  PosixPath('data/pubmed19n0409.xml.gz.md5'),
#  PosixPath('data/pubmed19n1117_stats.html'),
#  PosixPath('data/pubmed19n0579.xml.gz.md5'),
#  PosixPath('data/pubmed19n0532.xml.gz.md5'),
#  PosixPath('data/pubmed19n0264.xml.gz'),
#  PosixPath('data/pubmed19n1173.xml.gz'),
#  PosixPath('data/pubmed19n0174.xml.gz.md5'),
#  PosixPath('data/pubmed19n0610.xml.gz'),
#  PosixPath('data/pubmed19n0602.xml.gz.md5'),
#  PosixPath('data/pubmed19n1141.xml.gz.md5'),
#  PosixPath('data/pubmed19n0583.xml.gz'),
#  PosixPath('data/pubmed19n0527.xml.gz.md5'),
#  PosixPath('data/pubmed19n1133_stats.html'),
#  PosixPath('data/pubmed19n0868.xml.gz.md5'),
#  PosixPath('data/pubmed19n0515.xml.gz'),
#  PosixPath('data/pubmed19n0089.xml.gz.md5'),
#  PosixPath('data/pubmed19n0907.xml.gz'),
#  PosixPath('data/pubmed19n0816.xml.gz.md5'),
#  PosixPath('data/pubmed19n0660.xml.gz'),
#  PosixPath('data/pubmed19n0849.xml.gz'),
#  PosixPath('data/pubmed19n0315.xml.gz'),
#  PosixPath('data/pubmed19n0285.xml.gz'),
#  PosixPath('data/pubmed19n1101_stats.html'),
#  PosixPath('data/pubmed19n1047.xml.gz'),
#  PosixPath('data/pubmed19n0004.xml.gz'),
#  PosixPath('data/pubmed19n0200.xml.gz.md5'),
#  PosixPath('data/pubmed19n0410.xml.gz.md5'),
#  PosixPath('data/pubmed19n0005.xml.gz.md5'),
#  PosixPath('data/pubmed19n0130.xml.gz'),
#  PosixPath('data/pubmed19n0067.xml.gz.md5'),
#  PosixPath('data/pubmed19n0509.xml.gz.md5'),
#  PosixPath('data/pubmed19n0634.xml.gz.md5'),
#  PosixPath('data/pubmed19n1038.xml.gz.md5'),
#  PosixPath('data/pubmed19n0003.xml.gz.md5'),
#  PosixPath('data/pubmed19n0884.xml.gz.md5'),
#  PosixPath('data/pubmed19n0572.xml.gz.md5'),
#  PosixPath('data/pubmed19n0531.xml.gz'),
#  PosixPath('data/pubmed19n1178.xml.gz.md5'),
#  PosixPath('data/pubmed19n0403.xml.gz'),
#  PosixPath('data/pubmed19n0149.xml.gz'),
#  PosixPath('data/pubmed19n0698.xml.gz'),
#  PosixPath('data/pubmed19n0347.xml.gz.md5'),
#  PosixPath('data/pubmed19n0959.xml.gz'),
#  PosixPath('data/pubmed19n1020_stats.html'),
#  PosixPath('data/pubmed19n0740.xml.gz.md5'),
#  PosixPath('data/pubmed19n0979_stats.html'),
#  PosixPath('data/pubmed19n0918.xml.gz.md5'),
#  PosixPath('data/pubmed19n0276.xml.gz.md5'),
#  PosixPath('data/pubmed19n1052.xml.gz.md5'),
#  PosixPath('data/pubmed19n0570.xml.gz'),
#  PosixPath('data/pubmed19n1094.xml.gz.md5'),
#  PosixPath('data/pubmed19n0361.xml.gz.md5'),
#  PosixPath('data/pubmed19n0727.xml.gz'),
#  PosixPath('data/pubmed19n0666.xml.gz.md5'),
#  PosixPath('data/pubmed19n0168.xml.gz.md5'),
#  PosixPath('data/pubmed19n0330.xml.gz'),
#  PosixPath('data/pubmed19n0611.xml.gz'),
#  PosixPath('data/pubmed19n1162.xml.gz.md5'),
#  PosixPath('data/pubmed19n0813.xml.gz.md5'),
#  PosixPath('data/pubmed19n0437.xml.gz.md5'),
#  PosixPath('data/pubmed19n0620.xml.gz.md5'),
#  PosixPath('data/pubmed19n0983.xml.gz'),
#  PosixPath('data/pubmed19n0602.xml.gz'),
#  PosixPath('data/pubmed19n0759.xml.gz.md5'),
#  PosixPath('data/pubmed19n0518.xml.gz'),
#  PosixPath('data/pubmed19n0732.xml.gz.md5'),
#  PosixPath('data/pubmed19n0143.xml.gz'),
#  PosixPath('data/pubmed19n0223.xml.gz.md5'),
#  PosixPath('data/pubmed19n0738.xml.gz'),
#  PosixPath('data/pubmed19n0255.xml.gz.md5'),
#  PosixPath('data/pubmed19n1009.xml.gz'),
#  PosixPath('data/pubmed19n1118.xml.gz.md5'),
#  PosixPath('data/pubmed19n0356.xml.gz'),
#  PosixPath('data/pubmed19n0701.xml.gz'),
#  PosixPath('data/pubmed19n1134.xml.gz'),
#  PosixPath('data/pubmed19n0412.xml.gz'),
#  PosixPath('data/pubmed19n0159.xml.gz'),
#  PosixPath('data/pubmed19n0005.xml.gz'),
#  PosixPath('data/pubmed19n0153.xml.gz'),
#  PosixPath('data/pubmed19n0342.xml.gz'),
#  PosixPath('data/pubmed19n0123.xml.gz.md5'),
#  PosixPath('data/pubmed19n0074.xml.gz.md5'),
#  PosixPath('data/pubmed19n1198.xml.gz'),
#  PosixPath('data/pubmed19n1030.xml.gz'),
#  PosixPath('data/pubmed19n0854.xml.gz.md5'),
#  PosixPath('data/pubmed19n0508.xml.gz.md5'),
#  PosixPath('data/pubmed19n1091.xml.gz'),
#  PosixPath('data/pubmed19n0031.xml.gz.md5'),
#  PosixPath('data/pubmed19n0238.xml.gz'),
#  PosixPath('data/pubmed19n0103.xml.gz'),
#  PosixPath('data/pubmed19n1067_stats.html'),
#  PosixPath('data/pubmed19n0983_stats.html'),
#  PosixPath('data/pubmed19n1190.xml.gz.md5'),
#  PosixPath('data/pubmed19n1149.xml.gz'),
#  PosixPath('data/pubmed19n0113.xml.gz.md5'),
#  PosixPath('data/pubmed19n0262.xml.gz.md5'),
#  PosixPath('data/pubmed19n0091.xml.gz'),
#  PosixPath('data/pubmed19n0492.xml.gz.md5'),
#  PosixPath('data/pubmed19n0468.xml.gz'),
#  PosixPath('data/pubmed19n0568.xml.gz.md5'),
#  PosixPath('data/pubmed19n0386.xml.gz.md5'),
#  PosixPath('data/pubmed19n0874.xml.gz.md5'),
#  PosixPath('data/pubmed19n1079.xml.gz'),
#  PosixPath('data/pubmed19n0075.xml.gz'),
#  PosixPath('data/pubmed19n0620.xml.gz'),
#  PosixPath('data/pubmed19n0727.xml.gz.md5'),
#  PosixPath('data/pubmed19n0754.xml.gz'),
#  PosixPath('data/pubmed19n0648.xml.gz'),
#  PosixPath('data/pubmed19n0204.xml.gz.md5'),
#  PosixPath('data/pubmed19n0847.xml.gz.md5'),
#  PosixPath('data/pubmed19n0984_stats.html'),
#  PosixPath('data/pubmed19n1031_stats.html'),
#  PosixPath('data/pubmed19n0839.xml.gz'),
#  PosixPath('data/pubmed19n0077.xml.gz'),
#  PosixPath('data/pubmed19n1034.xml.gz'),
#  PosixPath('data/pubmed19n1175_stats.html'),
#  PosixPath('data/pubmed19n0493.xml.gz'),
#  PosixPath('data/pubmed19n0366.xml.gz.md5'),
#  PosixPath('data/pubmed19n1004.xml.gz.md5'),
#  PosixPath('data/pubmed19n0148.xml.gz'),
#  PosixPath('data/pubmed19n0548.xml.gz'),
#  PosixPath('data/pubmed19n1175.xml.gz'),
#  PosixPath('data/pubmed19n0774.xml.gz'),
#  PosixPath('data/pubmed19n0025.xml.gz.md5'),
#  PosixPath('data/pubmed19n0240.xml.gz.md5'),
#  PosixPath('data/pubmed19n0931.xml.gz'),
#  PosixPath('data/pubmed19n0123.xml.gz'),
#  PosixPath('data/pubmed19n1053.xml.gz.md5'),
#  PosixPath('data/pubmed19n1161.xml.gz.md5'),
#  PosixPath('data/pubmed19n1109_stats.html'),
#  PosixPath('data/pubmed19n0203.xml.gz.md5'),
#  PosixPath('data/pubmed19n0904.xml.gz'),
#  PosixPath('data/pubmed19n0996.xml.gz.md5'),
#  PosixPath('data/pubmed19n0091.xml.gz.md5'),
#  PosixPath('data/pubmed19n0992.xml.gz.md5'),
#  PosixPath('data/pubmed19n1043_stats.html'),
#  PosixPath('data/pubmed19n0278.xml.gz.md5'),
#  PosixPath('data/pubmed19n1006.xml.gz'),
#  PosixPath('data/pubmed19n0775.xml.gz'),
#  PosixPath('data/pubmed19n0542.xml.gz.md5'),
#  PosixPath('data/pubmed19n0063.xml.gz.md5'),
#  PosixPath('data/pubmed19n0762.xml.gz.md5'),
#  PosixPath('data/pubmed19n0001.xml.gz.md5'),
#  PosixPath('data/pubmed19n0948.xml.gz'),
#  PosixPath('data/pubmed19n0962.xml.gz.md5'),
#  PosixPath('data/pubmed19n0893.xml.gz.md5'),
#  PosixPath('data/pubmed19n0116.xml.gz.md5'),
#  PosixPath('data/pubmed19n0767.xml.gz.md5'),
#  PosixPath('data/pubmed19n0824.xml.gz'),
#  PosixPath('data/pubmed19n1192.xml.gz'),
#  PosixPath('data/pubmed19n0391.xml.gz.md5'),
#  PosixPath('data/pubmed19n0006.xml.gz.md5'),
#  PosixPath('data/pubmed19n1132.xml.gz.md5'),
#  PosixPath('data/pubmed19n0426.xml.gz.md5'),
#  PosixPath('data/pubmed19n0721.xml.gz'),
#  PosixPath('data/pubmed19n1013_stats.html'),
#  PosixPath('data/pubmed19n0317.xml.gz'),
#  PosixPath('data/pubmed19n0955.xml.gz'),
#  PosixPath('data/pubmed19n0545.xml.gz.md5'),
#  PosixPath('data/pubmed19n1131.xml.gz.md5'),
#  PosixPath('data/pubmed19n0186.xml.gz.md5'),
#  PosixPath('data/pubmed19n0191.xml.gz'),
#  PosixPath('data/pubmed19n0262.xml.gz'),
#  PosixPath('data/pubmed19n0349.xml.gz.md5'),
#  PosixPath('data/pubmed19n0643.xml.gz.md5'),
#  PosixPath('data/pubmed19n0890.xml.gz'),
#  PosixPath('data/pubmed19n0553.xml.gz'),
#  PosixPath('data/pubmed19n1094.xml.gz'),
#  PosixPath('data/pubmed19n0365.xml.gz.md5'),
#  PosixPath('data/pubmed19n0685.xml.gz'),
#  PosixPath('data/pubmed19n0277.xml.gz'),
#  PosixPath('data/pubmed19n0744.xml.gz.md5'),
#  PosixPath('data/pubmed19n1022.xml.gz.md5'),
#  PosixPath('data/pubmed19n1101.xml.gz.md5'),
#  PosixPath('data/pubmed19n0014.xml.gz.md5'),
#  PosixPath('data/pubmed19n0236.xml.gz.md5'),
#  PosixPath('data/pubmed19n0833.xml.gz'),
#  PosixPath('data/pubmed19n1118_stats.html'),
#  PosixPath('data/pubmed19n0863.xml.gz.md5'),
#  PosixPath('data/pubmed19n0561.xml.gz.md5'),
#  PosixPath('data/pubmed19n0534.xml.gz'),
#  PosixPath('data/pubmed19n0685.xml.gz.md5'),
#  PosixPath('data/pubmed19n1146.xml.gz'),
#  PosixPath('data/pubmed19n0975_stats.html'),
#  PosixPath('data/pubmed19n0547.xml.gz'),
#  PosixPath('data/pubmed19n0545.xml.gz'),
#  PosixPath('data/pubmed19n0986_stats.html'),
#  PosixPath('data/pubmed19n1123.xml.gz'),
#  PosixPath('data/pubmed19n0650.xml.gz.md5'),
#  PosixPath('data/pubmed19n0401.xml.gz'),
#  PosixPath('data/pubmed19n0626.xml.gz'),
#  PosixPath('data/pubmed19n0282.xml.gz.md5'),
#  PosixPath('data/pubmed19n0161.xml.gz'),
#  PosixPath('data/pubmed19n0871.xml.gz'),
#  PosixPath('data/pubmed19n0903.xml.gz.md5'),
#  PosixPath('data/pubmed19n0919.xml.gz'),
#  PosixPath('data/pubmed19n0319.xml.gz'),
#  PosixPath('data/pubmed19n0769.xml.gz'),
#  PosixPath('data/pubmed19n0779.xml.gz'),
#  PosixPath('data/pubmed19n0101.xml.gz.md5'),
#  PosixPath('data/pubmed19n0697.xml.gz'),
#  PosixPath('data/pubmed19n0305.xml.gz'),
#  PosixPath('data/pubmed19n0741.xml.gz.md5'),
#  PosixPath('data/pubmed19n1174.xml.gz'),
#  PosixPath('data/pubmed19n0061.xml.gz'),
#  PosixPath('data/pubmed19n1125.xml.gz'),
#  PosixPath('data/pubmed19n0943.xml.gz.md5'),
#  PosixPath('data/pubmed19n0574.xml.gz.md5'),
#  PosixPath('data/pubmed19n0484.xml.gz.md5'),
#  PosixPath('data/pubmed19n0940.xml.gz.md5'),
#  PosixPath('data/pubmed19n1085.xml.gz.md5'),
#  PosixPath('data/pubmed19n0011.xml.gz'),
#  PosixPath('data/pubmed19n0013.xml.gz'),
#  PosixPath('data/pubmed19n1159.xml.gz'),
#  PosixPath('data/pubmed19n1142_stats.html'),
#  PosixPath('data/pubmed19n1104_stats.html'),
#  PosixPath('data/pubmed19n0372.xml.gz'),
#  PosixPath('data/pubmed19n0209.xml.gz.md5'),
#  PosixPath('data/pubmed19n0233.xml.gz'),
#  PosixPath('data/pubmed19n1166_stats.html'),
#  PosixPath('data/pubmed19n1148.xml.gz'),
#  PosixPath('data/pubmed19n1093.xml.gz.md5'),
#  PosixPath('data/pubmed19n0530.xml.gz.md5'),
#  PosixPath('data/pubmed19n0715.xml.gz.md5'),
#  PosixPath('data/pubmed19n0068.xml.gz'),
#  PosixPath('data/pubmed19n1053_stats.html'),
#  PosixPath('data/pubmed19n1178_stats.html'),
#  PosixPath('data/pubmed19n0010.xml.gz'),
#  PosixPath('data/pubmed19n0910.xml.gz.md5'),
#  PosixPath('data/pubmed19n0351.xml.gz'),
#  PosixPath('data/pubmed19n1028.xml.gz'),
#  PosixPath('data/pubmed19n0993.xml.gz'),
#  PosixPath('data/pubmed19n0584.xml.gz.md5'),
#  PosixPath('data/pubmed19n0524.xml.gz.md5'),
#  PosixPath('data/pubmed19n0802.xml.gz'),
#  PosixPath('data/pubmed19n0457.xml.gz.md5'),
#  PosixPath('data/pubmed19n0445.xml.gz.md5'),
#  PosixPath('data/pubmed19n0449.xml.gz.md5'),
#  PosixPath('data/pubmed19n1112.xml.gz.md5'),
#  PosixPath('data/pubmed19n0159.xml.gz.md5'),
#  PosixPath('data/pubmed19n0913.xml.gz.md5'),
#  PosixPath('data/pubmed19n0408.xml.gz.md5'),
#  PosixPath('data/pubmed19n0705.xml.gz'),
#  PosixPath('data/pubmed19n0106.xml.gz.md5'),
#  PosixPath('data/pubmed19n0573.xml.gz'),
#  PosixPath('data/pubmed19n0224.xml.gz'),
#  PosixPath('data/pubmed19n0895.xml.gz'),
#  PosixPath('data/pubmed19n0131.xml.gz'),
#  PosixPath('data/pubmed19n0603.xml.gz.md5'),
#  PosixPath('data/pubmed19n1126.xml.gz.md5'),
#  PosixPath('data/pubmed19n0087.xml.gz.md5'),
#  PosixPath('data/pubmed19n0437.xml.gz'),
#  PosixPath('data/pubmed19n0430.xml.gz.md5'),
#  PosixPath('data/pubmed19n0137.xml.gz'),
#  PosixPath('data/pubmed19n1150_stats.html'),
#  PosixPath('data/pubmed19n1114.xml.gz.md5'),
#  PosixPath('data/pubmed19n0204.xml.gz'),
#  PosixPath('data/pubmed19n1133.xml.gz.md5'),
#  PosixPath('data/pubmed19n0541.xml.gz.md5'),
#  PosixPath('data/pubmed19n1129_stats.html'),
#  PosixPath('data/pubmed19n1070.xml.gz.md5'),
#  PosixPath('data/pubmed19n0163.xml.gz'),
#  PosixPath('data/pubmed19n0840.xml.gz.md5'),
#  PosixPath('data/pubmed19n0269.xml.gz.md5'),
#  PosixPath('data/pubmed19n0655.xml.gz'),
#  PosixPath('data/pubmed19n0350.xml.gz.md5'),
#  PosixPath('data/pubmed19n0404.xml.gz.md5'),
#  PosixPath('data/pubmed19n0281.xml.gz.md5'),
#  PosixPath('data/pubmed19n1037_stats.html'),
#  PosixPath('data/pubmed19n1195_stats.html'),
#  PosixPath('data/pubmed19n0337.xml.gz'),
#  PosixPath('data/pubmed19n1025.xml.gz.md5'),
#  PosixPath('data/pubmed19n0763.xml.gz.md5'),
#  PosixPath('data/pubmed19n0557.xml.gz.md5'),
#  PosixPath('data/pubmed19n0708.xml.gz'),
#  PosixPath('data/pubmed19n1102.xml.gz.md5'),
#  PosixPath('data/pubmed19n1055.xml.gz'),
#  PosixPath('data/pubmed19n0588.xml.gz.md5'),
#  PosixPath('data/pubmed19n0734.xml.gz'),
#  PosixPath('data/pubmed19n0973.xml.gz.md5'),
#  PosixPath('data/pubmed19n0140.xml.gz'),
#  PosixPath('data/pubmed19n0496.xml.gz'),
#  PosixPath('data/pubmed19n1127.xml.gz.md5'),
#  PosixPath('data/pubmed19n0283.xml.gz'),
#  PosixPath('data/pubmed19n1168_stats.html'),
#  PosixPath('data/pubmed19n0198.xml.gz.md5'),
#  PosixPath('data/pubmed19n0456.xml.gz'),
#  PosixPath('data/pubmed19n0456.xml.gz.md5'),
#  PosixPath('data/pubmed19n0867.xml.gz.md5'),
#  PosixPath('data/pubmed19n0701.xml.gz.md5'),
#  PosixPath('data/pubmed19n0294.xml.gz'),
#  PosixPath('data/pubmed19n0479.xml.gz.md5'),
#  PosixPath('data/pubmed19n0313.xml.gz'),
#  PosixPath('data/pubmed19n0980_stats.html'),
#  PosixPath('data/pubmed19n0044.xml.gz'),
#  PosixPath('data/pubmed19n1181.xml.gz.md5'),
#  PosixPath('data/pubmed19n1008.xml.gz'),
#  PosixPath('data/pubmed19n1130.xml.gz.md5'),
#  PosixPath('data/pubmed19n1106.xml.gz'),
#  PosixPath('data/pubmed19n0947.xml.gz.md5'),
#  PosixPath('data/pubmed19n1035_stats.html'),
#  PosixPath('data/pubmed19n0843.xml.gz.md5'),
#  PosixPath('data/pubmed19n0635.xml.gz.md5'),
#  PosixPath('data/pubmed19n0793.xml.gz'),
#  PosixPath('data/pubmed19n0175.xml.gz'),
#  PosixPath('data/pubmed19n0487.xml.gz'),
#  PosixPath('data/pubmed19n0934.xml.gz'),
#  PosixPath('data/pubmed19n1009_stats.html'),
#  PosixPath('data/pubmed19n1113.xml.gz.md5'),
#  PosixPath('data/pubmed19n0125.xml.gz'),
#  PosixPath('data/pubmed19n1113_stats.html'),
#  PosixPath('data/pubmed19n0621.xml.gz.md5'),
#  PosixPath('data/pubmed19n0930.xml.gz.md5'),
#  PosixPath('data/pubmed19n0482.xml.gz.md5'),
#  PosixPath('data/pubmed19n1042.xml.gz'),
#  PosixPath('data/pubmed19n1138.xml.gz.md5'),
#  PosixPath('data/pubmed19n0362.xml.gz.md5'),
#  PosixPath('data/pubmed19n1171.xml.gz.md5'),
#  PosixPath('data/pubmed19n1148.xml.gz.md5'),
#  PosixPath('data/pubmed19n1046.xml.gz.md5'),
#  PosixPath('data/pubmed19n1162_stats.html'),
#  PosixPath('data/pubmed19n0838.xml.gz'),
#  PosixPath('data/pubmed19n0104.xml.gz.md5'),
#  PosixPath('data/pubmed19n1012.xml.gz'),
#  PosixPath('data/pubmed19n1012_stats.html'),
#  PosixPath('data/pubmed19n0878.xml.gz.md5'),
#  PosixPath('data/pubmed19n0662.xml.gz.md5'),
#  PosixPath('data/pubmed19n1085_stats.html'),
#  PosixPath('data/pubmed19n0874.xml.gz'),
#  PosixPath('data/pubmed19n0136.xml.gz'),
#  PosixPath('data/pubmed19n0072.xml.gz'),
#  PosixPath('data/pubmed19n0306.xml.gz'),
#  PosixPath('data/pubmed19n0872.xml.gz'),
#  PosixPath('data/pubmed19n0244.xml.gz'),
#  PosixPath('data/pubmed19n0339.xml.gz'),
#  PosixPath('data/pubmed19n0859.xml.gz'),
#  PosixPath('data/pubmed19n0914.xml.gz.md5'),
#  PosixPath('data/pubmed19n0884.xml.gz'),
#  PosixPath('data/pubmed19n0086.xml.gz'),
#  PosixPath('data/pubmed19n0310.xml.gz'),
#  PosixPath('data/pubmed19n0092.xml.gz.md5'),
#  PosixPath('data/pubmed19n1192_stats.html'),
#  PosixPath('data/pubmed19n0510.xml.gz'),
#  PosixPath('data/pubmed19n0869.xml.gz.md5'),
#  PosixPath('data/pubmed19n0237.xml.gz.md5'),
#  PosixPath('data/pubmed19n1190.xml.gz'),
#  PosixPath('data/pubmed19n0436.xml.gz'),
#  PosixPath('data/pubmed19n0287.xml.gz.md5'),
#  PosixPath('data/pubmed19n0574.xml.gz'),
#  PosixPath('data/pubmed19n0571.xml.gz.md5'),
#  PosixPath('data/pubmed19n0169.xml.gz'),
#  PosixPath('data/pubmed19n0802.xml.gz.md5'),
#  PosixPath('data/pubmed19n0864.xml.gz'),
#  PosixPath('data/pubmed19n1080_stats.html'),
#  PosixPath('data/pubmed19n1060.xml.gz.md5'),
#  PosixPath('data/pubmed19n0156.xml.gz'),
#  PosixPath('data/pubmed19n0638.xml.gz'),
#  PosixPath('data/pubmed19n0095.xml.gz'),
#  PosixPath('data/pubmed19n1187_stats.html'),
#  PosixPath('data/pubmed19n1105.xml.gz'),
#  PosixPath('data/pubmed19n1193.xml.gz.md5'),
#  PosixPath('data/pubmed19n0241.xml.gz.md5'),
#  PosixPath('data/pubmed19n1132.xml.gz'),
#  PosixPath('data/pubmed19n1103_stats.html'),
#  PosixPath('data/pubmed19n1049_stats.html'),
#  PosixPath('data/pubmed19n1101.xml.gz'),
#  PosixPath('data/pubmed19n0325.xml.gz.md5'),
#  PosixPath('data/pubmed19n0446.xml.gz.md5'),
#  PosixPath('data/pubmed19n0022.xml.gz.md5'),
#  PosixPath('data/pubmed19n0232.xml.gz.md5'),
#  PosixPath('data/pubmed19n0493.xml.gz.md5'),
#  PosixPath('data/pubmed19n0111.xml.gz.md5'),
#  PosixPath('data/pubmed19n0206.xml.gz.md5'),
#  PosixPath('data/pubmed19n0443.xml.gz.md5'),
#  PosixPath('data/pubmed19n1161.xml.gz'),
#  PosixPath('data/pubmed19n0083.xml.gz'),
#  PosixPath('data/pubmed19n0212.xml.gz'),
#  PosixPath('data/pubmed19n0038.xml.gz.md5'),
#  PosixPath('data/pubmed19n0029.xml.gz'),
#  PosixPath('data/pubmed19n0471.xml.gz'),
#  PosixPath('data/pubmed19n0942.xml.gz.md5'),
#  PosixPath('data/pubmed19n0301.xml.gz.md5'),
#  PosixPath('data/pubmed19n0977.xml.gz.md5'),
#  PosixPath('data/pubmed19n1160.xml.gz'),
#  PosixPath('data/pubmed19n0101.xml.gz'),
#  PosixPath('data/pubmed19n0836.xml.gz.md5'),
#  PosixPath('data/pubmed19n0220.xml.gz.md5'),
#  PosixPath('data/pubmed19n1047.xml.gz.md5'),
#  PosixPath('data/pubmed19n0679.xml.gz'),
#  PosixPath('data/pubmed19n1127.xml.gz'),
#  PosixPath('data/pubmed19n0355.xml.gz.md5'),
#  PosixPath('data/pubmed19n0845.xml.gz'),
#  PosixPath('data/pubmed19n0381.xml.gz'),
#  PosixPath('data/pubmed19n0340.xml.gz'),
#  PosixPath('data/pubmed19n0629.xml.gz'),
#  PosixPath('data/pubmed19n0451.xml.gz.md5'),
#  PosixPath('data/pubmed19n1171.xml.gz'),
#  PosixPath('data/pubmed19n0681.xml.gz.md5'),
#  PosixPath('data/pubmed19n0613.xml.gz.md5'),
#  PosixPath('data/pubmed19n1076_stats.html'),
#  PosixPath('data/pubmed19n0055.xml.gz.md5'),
#  PosixPath('data/pubmed19n0486.xml.gz'),
#  PosixPath('data/pubmed19n0680.xml.gz.md5'),
#  PosixPath('data/pubmed19n0590.xml.gz.md5'),
#  PosixPath('data/pubmed19n0664.xml.gz'),
#  PosixPath('data/pubmed19n0815.xml.gz.md5'),
#  PosixPath('data/pubmed19n0535.xml.gz'),
#  PosixPath('data/pubmed19n0180.xml.gz'),
#  PosixPath('data/pubmed19n0539.xml.gz.md5'),
#  PosixPath('data/pubmed19n1122.xml.gz.md5'),
#  PosixPath('data/pubmed19n1046_stats.html'),
#  PosixPath('data/pubmed19n0650.xml.gz'),
#  PosixPath('data/pubmed19n0928.xml.gz.md5'),
#  PosixPath('data/pubmed19n0514.xml.gz'),
#  PosixPath('data/pubmed19n0601.xml.gz'),
#  PosixPath('data/pubmed19n1049.xml.gz'),
#  PosixPath('data/pubmed19n0120.xml.gz'),
#  PosixPath('data/pubmed19n1088.xml.gz'),
#  PosixPath('data/pubmed19n1025.xml.gz'),
#  PosixPath('data/pubmed19n0286.xml.gz.md5'),
#  PosixPath('data/pubmed19n1090.xml.gz'),
#  PosixPath('data/pubmed19n0105.xml.gz.md5'),
#  PosixPath('data/pubmed19n0726.xml.gz'),
#  PosixPath('data/pubmed19n0096.xml.gz'),
#  PosixPath('data/pubmed19n0302.xml.gz.md5'),
#  PosixPath('data/pubmed19n0969.xml.gz.md5'),
#  PosixPath('data/pubmed19n0975.xml.gz'),
#  PosixPath('data/pubmed19n0248.xml.gz'),
#  PosixPath('data/pubmed19n0207.xml.gz.md5'),
#  PosixPath('data/pubmed19n0868.xml.gz'),
#  PosixPath('data/pubmed19n0673.xml.gz.md5'),
#  PosixPath('data/pubmed19n1037.xml.gz'),
#  PosixPath('data/pubmed19n0881.xml.gz.md5'),
#  PosixPath('data/pubmed19n1064.xml.gz.md5'),
#  PosixPath('data/pubmed19n0060.xml.gz.md5'),
#  PosixPath('data/pubmed19n1164.xml.gz'),
#  PosixPath('data/pubmed19n1186.xml.gz'),
#  PosixPath('data/pubmed19n0742.xml.gz'),
#  PosixPath('data/pubmed19n0764.xml.gz'),
#  PosixPath('data/pubmed19n0144.xml.gz'),
#  PosixPath('data/pubmed19n0131.xml.gz.md5'),
#  PosixPath('data/pubmed19n0395.xml.gz.md5'),
#  PosixPath('data/pubmed19n1092_stats.html'),
#  PosixPath('data/pubmed19n0546.xml.gz'),
#  PosixPath('data/pubmed19n0172.xml.gz.md5'),
#  PosixPath('data/pubmed19n0499.xml.gz'),
#  PosixPath('data/pubmed19n0491.xml.gz'),
#  PosixPath('data/pubmed19n1129.xml.gz.md5'),
#  PosixPath('data/pubmed19n0436.xml.gz.md5'),
#  PosixPath('data/pubmed19n0303.xml.gz'),
#  PosixPath('data/pubmed19n1048.xml.gz'),
#  PosixPath('data/pubmed19n0355.xml.gz'),
#  PosixPath('data/pubmed19n0661.xml.gz.md5'),
#  PosixPath('data/pubmed19n0712.xml.gz'),
#  PosixPath('data/pubmed19n0228.xml.gz'),
#  PosixPath('data/pubmed19n0713.xml.gz'),
#  PosixPath('data/pubmed19n1042.xml.gz.md5'),
#  PosixPath('data/pubmed19n0237.xml.gz'),
#  PosixPath('data/pubmed19n0586.xml.gz.md5'),
#  PosixPath('data/pubmed19n0385.xml.gz.md5'),
#  PosixPath('data/pubmed19n0901.xml.gz'),
#  PosixPath('data/pubmed19n0158.xml.gz'),
#  PosixPath('data/pubmed19n0897.xml.gz.md5'),
#  PosixPath('data/pubmed19n0699.xml.gz.md5'),
#  PosixPath('data/pubmed19n0995_stats.html'),
#  PosixPath('data/pubmed19n0039.xml.gz'),
#  PosixPath('data/pubmed19n0402.xml.gz.md5'),
#  PosixPath('data/pubmed19n0308.xml.gz.md5'),
#  PosixPath('data/pubmed19n0648.xml.gz.md5'),
#  PosixPath('data/pubmed19n0179.xml.gz.md5'),
#  PosixPath('data/pubmed19n0882.xml.gz'),
#  PosixPath('data/pubmed19n0968.xml.gz'),
#  PosixPath('data/pubmed19n0501.xml.gz'),
#  PosixPath('data/pubmed19n0375.xml.gz.md5'),
#  PosixPath('data/pubmed19n1140_stats.html'),
#  PosixPath('data/pubmed19n0804.xml.gz'),
#  PosixPath('data/pubmed19n0386.xml.gz'),
#  PosixPath('data/pubmed19n0985.xml.gz'),
#  PosixPath('data/pubmed19n0552.xml.gz'),
#  PosixPath('data/pubmed19n0086.xml.gz.md5'),
#  PosixPath('data/pubmed19n0985_stats.html'),
#  PosixPath('data/pubmed19n0753.xml.gz'),
#  PosixPath('data/pubmed19n0245.xml.gz'),
#  PosixPath('data/pubmed19n0794.xml.gz'),
#  PosixPath('data/pubmed19n1033.xml.gz'),
#  PosixPath('data/pubmed19n0030.xml.gz'),
#  PosixPath('data/pubmed19n1152_stats.html'),
#  PosixPath('data/pubmed19n0600.xml.gz'),
#  PosixPath('data/pubmed19n0075.xml.gz.md5'),
#  PosixPath('data/pubmed19n0374.xml.gz.md5'),
#  PosixPath('data/pubmed19n0899.xml.gz'),
#  PosixPath('data/pubmed19n0461.xml.gz.md5'),
#  PosixPath('data/pubmed19n0129.xml.gz.md5'),
#  PosixPath('data/pubmed19n0580.xml.gz'),
#  PosixPath('data/pubmed19n0370.xml.gz'),
#  PosixPath('data/pubmed19n0634.xml.gz'),
#  PosixPath('data/pubmed19n1066.xml.gz.md5'),
#  PosixPath('data/pubmed19n0600.xml.gz.md5'),
#  PosixPath('data/pubmed19n0772.xml.gz.md5'),
#  PosixPath('data/pubmed19n1170_stats.html'),
#  PosixPath('data/pubmed19n0695.xml.gz'),
#  PosixPath('data/pubmed19n1123_stats.html'),
#  PosixPath('data/pubmed19n1082.xml.gz.md5'),
#  PosixPath('data/pubmed19n1057.xml.gz.md5'),
#  PosixPath('data/pubmed19n0020.xml.gz.md5'),
#  PosixPath('data/pubmed19n1107.xml.gz'),
#  PosixPath('data/pubmed19n0312.xml.gz'),
#  PosixPath('data/pubmed19n0017.xml.gz'),
#  PosixPath('data/pubmed19n0945.xml.gz'),
#  PosixPath('data/pubmed19n0777.xml.gz'),
#  PosixPath('data/pubmed19n0626.xml.gz.md5'),
#  PosixPath('data/pubmed19n1008.xml.gz.md5'),
#  PosixPath('data/pubmed19n0395.xml.gz'),
#  PosixPath('data/pubmed19n0675.xml.gz'),
#  PosixPath('data/pubmed19n1050_stats.html'),
#  PosixPath('data/pubmed19n1147.xml.gz'),
#  PosixPath('data/pubmed19n0672.xml.gz'),
#  PosixPath('data/pubmed19n1084_stats.html'),
#  PosixPath('data/pubmed19n0259.xml.gz.md5'),
#  PosixPath('data/pubmed19n0229.xml.gz'),
#  PosixPath('data/pubmed19n0513.xml.gz'),
#  PosixPath('data/pubmed19n1102_stats.html'),
#  PosixPath('data/pubmed19n0440.xml.gz'),
#  PosixPath('data/pubmed19n0708.xml.gz.md5'),
#  PosixPath('data/pubmed19n0518.xml.gz.md5'),
#  PosixPath('data/pubmed19n0171.xml.gz.md5'),
#  PosixPath('data/pubmed19n0188.xml.gz.md5'),
#  PosixPath('data/pubmed19n0459.xml.gz.md5'),
#  PosixPath('data/pubmed19n1183.xml.gz'),
#  PosixPath('data/pubmed19n1092.xml.gz.md5'),
#  PosixPath('data/pubmed19n1111_stats.html'),
#  PosixPath('data/pubmed19n0976.xml.gz'),
#  PosixPath('data/pubmed19n0361.xml.gz'),
#  PosixPath('data/pubmed19n0326.xml.gz.md5'),
#  PosixPath('data/pubmed19n0473.xml.gz.md5'),
#  PosixPath('data/pubmed19n1114.xml.gz'),
#  PosixPath('data/pubmed19n0335.xml.gz'),
#  PosixPath('data/pubmed19n0619.xml.gz'),
#  PosixPath('data/pubmed19n1103.xml.gz.md5'),
#  PosixPath('data/pubmed19n0439.xml.gz'),
#  PosixPath('data/pubmed19n0215.xml.gz.md5'),
#  PosixPath('data/pubmed19n0982.xml.gz'),
#  PosixPath('data/pubmed19n1022.xml.gz'),
#  PosixPath('data/pubmed19n0074.xml.gz'),
#  PosixPath('data/pubmed19n0124.xml.gz'),
#  PosixPath('data/pubmed19n1090.xml.gz.md5'),
#  PosixPath('data/pubmed19n1007.xml.gz'),
#  PosixPath('data/pubmed19n0924.xml.gz'),
#  PosixPath('data/pubmed19n0851.xml.gz.md5'),
#  PosixPath('data/pubmed19n1054.xml.gz'),
#  PosixPath('data/pubmed19n0429.xml.gz.md5'),
#  PosixPath('data/pubmed19n0938.xml.gz.md5'),
#  PosixPath('data/pubmed19n1018.xml.gz'),
#  PosixPath('data/pubmed19n1000.xml.gz.md5'),
#  PosixPath('data/pubmed19n0372.xml.gz.md5'),
#  PosixPath('data/pubmed19n0190.xml.gz'),
#  PosixPath('data/pubmed19n0477.xml.gz.md5'),
#  PosixPath('data/pubmed19n0760.xml.gz'),
#  PosixPath('data/pubmed19n0032.xml.gz'),
#  PosixPath('data/pubmed19n0699.xml.gz'),
#  PosixPath('data/pubmed19n1119.xml.gz'),
#  PosixPath('data/pubmed19n0069.xml.gz.md5'),
#  PosixPath('data/pubmed19n0072.xml.gz.md5'),
#  PosixPath('data/pubmed19n0777.xml.gz.md5'),
#  PosixPath('data/pubmed19n0085.xml.gz'),
#  PosixPath('data/pubmed19n0724.xml.gz.md5'),
#  PosixPath('data/pubmed19n1095_stats.html'),
#  PosixPath('data/pubmed19n1179_stats.html'),
#  PosixPath('data/pubmed19n0375.xml.gz'),
#  PosixPath('data/pubmed19n1134.xml.gz.md5'),
#  PosixPath('data/pubmed19n0945.xml.gz.md5'),
#  PosixPath('data/pubmed19n0341.xml.gz'),
#  PosixPath('data/pubmed19n0582.xml.gz.md5'),
#  PosixPath('data/pubmed19n0617.xml.gz.md5'),
#  PosixPath('data/pubmed19n1180.xml.gz.md5'),
#  PosixPath('data/pubmed19n0398.xml.gz'),
#  PosixPath('data/pubmed19n0993.xml.gz.md5'),
#  PosixPath('data/pubmed19n0704.xml.gz'),
#  PosixPath('data/pubmed19n0035.xml.gz'),
#  PosixPath('data/pubmed19n0062.xml.gz'),
#  PosixPath('data/pubmed19n0979.xml.gz'),
#  PosixPath('data/pubmed19n0118.xml.gz.md5'),
#  PosixPath('data/pubmed19n0200.xml.gz'),
#  PosixPath('data/pubmed19n0873.xml.gz'),
#  PosixPath('data/pubmed19n0567.xml.gz.md5'),
#  PosixPath('data/pubmed19n0370.xml.gz.md5'),
#  PosixPath('data/pubmed19n0929.xml.gz.md5'),
#  PosixPath('data/pubmed19n0689.xml.gz'),
#  PosixPath('data/pubmed19n0336.xml.gz'),
#  PosixPath('data/pubmed19n0852.xml.gz.md5'),
#  PosixPath('data/pubmed19n0529.xml.gz'),
#  PosixPath('data/pubmed19n0296.xml.gz.md5'),
#  PosixPath('data/pubmed19n0369.xml.gz'),
#  PosixPath('data/pubmed19n1058.xml.gz'),
#  PosixPath('data/pubmed19n0732.xml.gz'),
#  PosixPath('data/pubmed19n1156.xml.gz.md5'),
#  PosixPath('data/pubmed19n0644.xml.gz.md5'),
#  PosixPath('data/pubmed19n0427.xml.gz'),
#  PosixPath('data/pubmed19n0876.xml.gz'),
#  PosixPath('data/pubmed19n1170.xml.gz.md5'),
#  PosixPath('data/pubmed19n0954.xml.gz.md5'),
#  PosixPath('data/pubmed19n0428.xml.gz'),
#  PosixPath('data/pubmed19n0271.xml.gz'),
#  PosixPath('data/pubmed19n1121_stats.html'),
#  PosixPath('data/pubmed19n0835.xml.gz.md5'),
#  PosixPath('data/pubmed19n0114.xml.gz.md5'),
#  PosixPath('data/pubmed19n0819.xml.gz'),
#  PosixPath('data/pubmed19n0337.xml.gz.md5'),
#  PosixPath('data/pubmed19n0181.xml.gz.md5'),
#  PosixPath('data/pubmed19n0987.xml.gz'),
#  ...]

# %% [markdown]
# ## Extraction

# %%
# Data to extract:

# Root: PubmedArticleSet.PubmedArticle.MedlineCitation

#  Condition: # only english articles
# -- .Language == eng

# 1. pmid | title | abstract | mesh (pubmed-abstracts.csv)
# - .PMID
# - .Article:
# -- .ArticleTitle
# -- .Abstract.AbstractText
#
# 2.  MeSH data 
# - .MeshHeadingList: converted into a single record with '|' separated entries of each MeshHeading
#    and each MeshHeading is converted into 'UI/MajorTopicYN' for DescriptorName, 
#    and optional 'UI/MajorTopicYN' for QualifierName joined with '-' 
#    here is a sample of what a record might look like: D000339/Y|D004650/N-Q000706/Y 
# 
#   the lookup table for these ids is saved in a separate pubmed-mesh.csv file

mesh_db = {}

def mesh_db_update(k, v):
    if k in mesh_db: return
    mesh_db[k]=v
    
def mesh_db_write(csv_writer_mesh):
    print(f"Saving MeSh records ({len(mesh_db)})")
    csv_writer_mesh.writerows(sorted(mesh_db.items()))
            
# https://stackoverflow.com/a/26435241/9201239 efficient RAM usage
def parse_entries(f, tag):
    """Yield *tag* elements from *f* xml (fn or fh) incrementaly."""
    context = iter(etree.iterparse(f, events=('start', 'end')))
    _, root = next(context) # get root element
    for event, elem in context:
        if event == 'end' and elem.tag == tag:
            yield elem
            root.clear() # free memory

def meshhead2rec(mh):
    if mh is None: return ''
    l = []
    for e in mh.find('DescriptorName'), mh.find('QualifierName'):
        if e is not None:
            ui, mt = e.attrib['UI'], e.attrib['MajorTopicYN']
            l.append(f"{ui}/{mt}")
            mesh_db_update(ui, e.text)
    return "-".join(l)
                
def meshlist2rec(mhl):
    if mhl is None: return ''
    l = [meshhead2rec(m) for m in mhl.findall('MeshHeading')]
    return "|".join(l)

def extract(f_in, fn, files_cnt, csv_writer_main):
    c  = 0
    c_eng = 0
    c_no_abstract = 0
    for e in parse_entries(f_in, 'MedlineCitation'):
        c += 1
        try:
            pmid = e.find('PMID').text
            #print(pmid)

            # 1. Abstracts
            a = e.find('Article')
            if a is None: continue
                
            lang = a.find('Language')
            if lang is None or lang.text != 'eng': continue

            c_eng += 1
            title    = a.find('ArticleTitle').text
            abstract = a.find('Abstract')
            if abstract is not None:
                abstract_text = abstract.find('AbstractText').text
                #print(pmid, title, abstract)
            else:
                abstract_text = ''
                c_no_abstract += 1

            
            # 2. MeSH Data
            mesh = meshlist2rec(e.find('MeshHeadingList'))
            #print(f"MeSH: {mesh}")
            
            # 
            csv_writer_main.writerow([pmid, title, abstract_text, mesh])
                    
        except: 
            #if not pmid: pmid = "unknown"
            #print(f"{pmid} failed to parse")
            raise
        #break
        
    print(f"{files_cnt:0>4d} {fn}: recs {c:0>5d}, eng {c_eng:0>5d}, no abstract {c_no_abstract:0>5d}")
    
    return c, c_eng, c_no_abstract

def process():

    csv_fn_main = dest/"pubmed-abstracts.csv"
    csv_fn_mesh = dest/"pubmed-mesh.csv"
    files_cnt = 0
    with open(csv_fn_main, "w") as f_out_main, open(csv_fn_mesh, "w") as f_out_mesh:
        csv_writer_main = csv.writer(f_out_main)
        csv_writer_mesh = csv.writer(f_out_mesh)
        
        csv_writer_main.writerow(["pmid", "title", "abstract", "mesh"])
        csv_writer_mesh.writerow(["meshid", "text"])
        
        total, total_eng, total_no_abstract = 0, 0, 0
        files = sorted(path.glob("*.xml.gz"))
        print(f"Total files to process: {len(files)}")
        for fn in files:
            files_cnt += 1
            #fn = path/"pubmed19n1206.xml.gz"
            with gzip.open(fn, 'rb') as f_in: 
                c, c_eng, c_no_abstract = extract(f_in, fn, files_cnt, csv_writer_main)
                total             += c
                total_eng         += c_eng
                total_no_abstract += c_no_abstract
        print(f"Grand total of {total_eng:,} English recs (no abstract {total_no_abstract:,}) out of {total:,} pubmed recs")
        # save MeSH records
        mesh_db_write(csv_writer_mesh)
        
    # summary
    ! wc -l {csv_fn_main} {csv_fn_mesh}
    ! ls -l {csv_fn_main} {csv_fn_mesh}
    
    # gzip, keep the original
    ! gzip -k {csv_fn_main} {csv_fn_mesh}
    ! ls -l {csv_fn_main}.gz {csv_fn_mesh}.gz
    
# %time process()
# Out:
# Total files to process: 1206
# 0001 data/pubmed19n0001.xml.gz: recs 30000, eng 23211, no abstract 10488
# 0002 data/pubmed19n0002.xml.gz: recs 30000, eng 23891, no abstract 12560
# 0003 data/pubmed19n0003.xml.gz: recs 30000, eng 24221, no abstract 13481
# 0004 data/pubmed19n0004.xml.gz: recs 30000, eng 22116, no abstract 10006
# 0005 data/pubmed19n0005.xml.gz: recs 30000, eng 17000, no abstract 07522
# 0006 data/pubmed19n0006.xml.gz: recs 30000, eng 22584, no abstract 08940
# 0007 data/pubmed19n0007.xml.gz: recs 30000, eng 23679, no abstract 09807
# 0008 data/pubmed19n0008.xml.gz: recs 30000, eng 24132, no abstract 10796
# 0009 data/pubmed19n0009.xml.gz: recs 30000, eng 19776, no abstract 14990
# 0010 data/pubmed19n0010.xml.gz: recs 30000, eng 19958, no abstract 11925
# 0011 data/pubmed19n0011.xml.gz: recs 30000, eng 21843, no abstract 10365
# 0012 data/pubmed19n0012.xml.gz: recs 30000, eng 20486, no abstract 10566
# 0013 data/pubmed19n0013.xml.gz: recs 30000, eng 20617, no abstract 10889
# 0014 data/pubmed19n0014.xml.gz: recs 30000, eng 22290, no abstract 10101
# 0015 data/pubmed19n0015.xml.gz: recs 30000, eng 22654, no abstract 10822
# 0016 data/pubmed19n0016.xml.gz: recs 30000, eng 21492, no abstract 09860
# 0017 data/pubmed19n0017.xml.gz: recs 30000, eng 21278, no abstract 10719
# 0018 data/pubmed19n0018.xml.gz: recs 30000, eng 18508, no abstract 09708
# 0019 data/pubmed19n0019.xml.gz: recs 30000, eng 20324, no abstract 09646
# 0020 data/pubmed19n0020.xml.gz: recs 30000, eng 18180, no abstract 10466
# 0021 data/pubmed19n0021.xml.gz: recs 30000, eng 21318, no abstract 10823
# 0022 data/pubmed19n0022.xml.gz: recs 30000, eng 20060, no abstract 09802
# 0023 data/pubmed19n0023.xml.gz: recs 30000, eng 19386, no abstract 09706
# 0024 data/pubmed19n0024.xml.gz: recs 30000, eng 20048, no abstract 10009
# 0025 data/pubmed19n0025.xml.gz: recs 30000, eng 19041, no abstract 10199
# 0026 data/pubmed19n0026.xml.gz: recs 30000, eng 20306, no abstract 10628
# 0027 data/pubmed19n0027.xml.gz: recs 30000, eng 20910, no abstract 08958
# 0028 data/pubmed19n0028.xml.gz: recs 30000, eng 22280, no abstract 10155
# 0029 data/pubmed19n0029.xml.gz: recs 30000, eng 21046, no abstract 10038
# 0030 data/pubmed19n0030.xml.gz: recs 30000, eng 19969, no abstract 10479
# 0031 data/pubmed19n0031.xml.gz: recs 30000, eng 20898, no abstract 09783
# 0032 data/pubmed19n0032.xml.gz: recs 30000, eng 20858, no abstract 10165
# 0033 data/pubmed19n0033.xml.gz: recs 30000, eng 18278, no abstract 08414
# 0034 data/pubmed19n0034.xml.gz: recs 30000, eng 14650, no abstract 09726
# 0035 data/pubmed19n0035.xml.gz: recs 30000, eng 20515, no abstract 14415
# 0036 data/pubmed19n0036.xml.gz: recs 30000, eng 20103, no abstract 10290
# 0037 data/pubmed19n0037.xml.gz: recs 30000, eng 23037, no abstract 12052
# 0038 data/pubmed19n0038.xml.gz: recs 30000, eng 21564, no abstract 10883
# 0039 data/pubmed19n0039.xml.gz: recs 30000, eng 21930, no abstract 10415
# 0040 data/pubmed19n0040.xml.gz: recs 30000, eng 15973, no abstract 08677
# 0041 data/pubmed19n0041.xml.gz: recs 30000, eng 16022, no abstract 07646
# 0042 data/pubmed19n0042.xml.gz: recs 30000, eng 22996, no abstract 09379
# 0043 data/pubmed19n0043.xml.gz: recs 30000, eng 20729, no abstract 05297
# 0044 data/pubmed19n0044.xml.gz: recs 30000, eng 24996, no abstract 03509
# 0045 data/pubmed19n0045.xml.gz: recs 30000, eng 26148, no abstract 07099
# 0046 data/pubmed19n0046.xml.gz: recs 30000, eng 27228, no abstract 04955
# 0047 data/pubmed19n0047.xml.gz: recs 30000, eng 25051, no abstract 06127
# 0048 data/pubmed19n0048.xml.gz: recs 30000, eng 23998, no abstract 06189
# 0049 data/pubmed19n0049.xml.gz: recs 30000, eng 23768, no abstract 05974
# 0050 data/pubmed19n0050.xml.gz: recs 30000, eng 25530, no abstract 06612
# 0051 data/pubmed19n0051.xml.gz: recs 30000, eng 26415, no abstract 06607
# 0052 data/pubmed19n0052.xml.gz: recs 30000, eng 25943, no abstract 06528
# 0053 data/pubmed19n0053.xml.gz: recs 30000, eng 25729, no abstract 06765
# 0054 data/pubmed19n0054.xml.gz: recs 30000, eng 25704, no abstract 06503
# 0055 data/pubmed19n0055.xml.gz: recs 30000, eng 25164, no abstract 04534
# 0056 data/pubmed19n0056.xml.gz: recs 30000, eng 26558, no abstract 05252
# 0057 data/pubmed19n0057.xml.gz: recs 30000, eng 26526, no abstract 04224
# 0058 data/pubmed19n0058.xml.gz: recs 30000, eng 25400, no abstract 06699
# 0059 data/pubmed19n0059.xml.gz: recs 30000, eng 22201, no abstract 05118
# 0060 data/pubmed19n0060.xml.gz: recs 30000, eng 21192, no abstract 05669
# 0061 data/pubmed19n0061.xml.gz: recs 30000, eng 23398, no abstract 04634
# 0062 data/pubmed19n0062.xml.gz: recs 30000, eng 23859, no abstract 06395
# 0063 data/pubmed19n0063.xml.gz: recs 30000, eng 25575, no abstract 05876
# 0064 data/pubmed19n0064.xml.gz: recs 30000, eng 25231, no abstract 06078
# 0065 data/pubmed19n0065.xml.gz: recs 30000, eng 23880, no abstract 06650
# 0066 data/pubmed19n0066.xml.gz: recs 30000, eng 27699, no abstract 08237
# 0067 data/pubmed19n0067.xml.gz: recs 30000, eng 26686, no abstract 07104
# 0068 data/pubmed19n0068.xml.gz: recs 30000, eng 24124, no abstract 06720
# 0069 data/pubmed19n0069.xml.gz: recs 30000, eng 20919, no abstract 05599
# 0070 data/pubmed19n0070.xml.gz: recs 30000, eng 23471, no abstract 05852
# 0071 data/pubmed19n0071.xml.gz: recs 30000, eng 22063, no abstract 04770
# 0072 data/pubmed19n0072.xml.gz: recs 30000, eng 25362, no abstract 03979
# 0073 data/pubmed19n0073.xml.gz: recs 30000, eng 24376, no abstract 06386
# 0074 data/pubmed19n0074.xml.gz: recs 30000, eng 22898, no abstract 06974
# 0075 data/pubmed19n0075.xml.gz: recs 30000, eng 23221, no abstract 06000
# 0076 data/pubmed19n0076.xml.gz: recs 30000, eng 23557, no abstract 06684
# 0077 data/pubmed19n0077.xml.gz: recs 30000, eng 26151, no abstract 07368
# 0078 data/pubmed19n0078.xml.gz: recs 30000, eng 24421, no abstract 06388
# 0079 data/pubmed19n0079.xml.gz: recs 30000, eng 23678, no abstract 07079
# 0080 data/pubmed19n0080.xml.gz: recs 30000, eng 24818, no abstract 05001
# 0081 data/pubmed19n0081.xml.gz: recs 30000, eng 25194, no abstract 03735
# 0082 data/pubmed19n0082.xml.gz: recs 30000, eng 25054, no abstract 03718
# 0083 data/pubmed19n0083.xml.gz: recs 30000, eng 24222, no abstract 06532
# 0084 data/pubmed19n0084.xml.gz: recs 30000, eng 23319, no abstract 04534
# 0085 data/pubmed19n0085.xml.gz: recs 30000, eng 25854, no abstract 05422
# 0086 data/pubmed19n0086.xml.gz: recs 30000, eng 22931, no abstract 05788
# 0087 data/pubmed19n0087.xml.gz: recs 30000, eng 19153, no abstract 04890
# 0088 data/pubmed19n0088.xml.gz: recs 30000, eng 22574, no abstract 06807
# 0089 data/pubmed19n0089.xml.gz: recs 30000, eng 22979, no abstract 06086
# 0090 data/pubmed19n0090.xml.gz: recs 30000, eng 23355, no abstract 06572
# 0091 data/pubmed19n0091.xml.gz: recs 30000, eng 22622, no abstract 06373
# 0092 data/pubmed19n0092.xml.gz: recs 30000, eng 24127, no abstract 06338
# 0093 data/pubmed19n0093.xml.gz: recs 30000, eng 22973, no abstract 05315
# 0094 data/pubmed19n0094.xml.gz: recs 30000, eng 24865, no abstract 04335
# 0095 data/pubmed19n0095.xml.gz: recs 30000, eng 25406, no abstract 07308
# 0096 data/pubmed19n0096.xml.gz: recs 30000, eng 26470, no abstract 09033
# 0097 data/pubmed19n0097.xml.gz: recs 30000, eng 26332, no abstract 07558
# 0098 data/pubmed19n0098.xml.gz: recs 30000, eng 20550, no abstract 05178
# 0099 data/pubmed19n0099.xml.gz: recs 30000, eng 23478, no abstract 04838
# 0100 data/pubmed19n0100.xml.gz: recs 30000, eng 25506, no abstract 03885
# 0101 data/pubmed19n0101.xml.gz: recs 30000, eng 24550, no abstract 05364
# 0102 data/pubmed19n0102.xml.gz: recs 30000, eng 21561, no abstract 08680
# 0103 data/pubmed19n0103.xml.gz: recs 30000, eng 25015, no abstract 07354
# 0104 data/pubmed19n0104.xml.gz: recs 30000, eng 25520, no abstract 07564
# 0105 data/pubmed19n0105.xml.gz: recs 30000, eng 22581, no abstract 07807
# 0106 data/pubmed19n0106.xml.gz: recs 30000, eng 23058, no abstract 07797
# 0107 data/pubmed19n0107.xml.gz: recs 30000, eng 19808, no abstract 07348
# 0108 data/pubmed19n0108.xml.gz: recs 30000, eng 20113, no abstract 07310
# 0109 data/pubmed19n0109.xml.gz: recs 30000, eng 22573, no abstract 08486
# 0110 data/pubmed19n0110.xml.gz: recs 30000, eng 22946, no abstract 07818
# 0111 data/pubmed19n0111.xml.gz: recs 30000, eng 24671, no abstract 09062
# 0112 data/pubmed19n0112.xml.gz: recs 30000, eng 24287, no abstract 08074
# 0113 data/pubmed19n0113.xml.gz: recs 30000, eng 23083, no abstract 07772
# 0114 data/pubmed19n0114.xml.gz: recs 30000, eng 20953, no abstract 07437
# 0115 data/pubmed19n0115.xml.gz: recs 30000, eng 20585, no abstract 09956
# 0116 data/pubmed19n0116.xml.gz: recs 30000, eng 23024, no abstract 07172
# 0117 data/pubmed19n0117.xml.gz: recs 30000, eng 22765, no abstract 07331
# 0118 data/pubmed19n0118.xml.gz: recs 30000, eng 22532, no abstract 07179
# 0119 data/pubmed19n0119.xml.gz: recs 30000, eng 22708, no abstract 06987
# 0120 data/pubmed19n0120.xml.gz: recs 30000, eng 22360, no abstract 06638
# 0121 data/pubmed19n0121.xml.gz: recs 30000, eng 21180, no abstract 13207
# 0122 data/pubmed19n0122.xml.gz: recs 30000, eng 22993, no abstract 07666
# 0123 data/pubmed19n0123.xml.gz: recs 30000, eng 23004, no abstract 08031
# 0124 data/pubmed19n0124.xml.gz: recs 30000, eng 22655, no abstract 06851
# 0125 data/pubmed19n0125.xml.gz: recs 30000, eng 22977, no abstract 07083
# 0126 data/pubmed19n0126.xml.gz: recs 30000, eng 22448, no abstract 06484
# 0127 data/pubmed19n0127.xml.gz: recs 30000, eng 21115, no abstract 06850
# 0128 data/pubmed19n0128.xml.gz: recs 30000, eng 21204, no abstract 11924
# 0129 data/pubmed19n0129.xml.gz: recs 30000, eng 22668, no abstract 07130
# 0130 data/pubmed19n0130.xml.gz: recs 30000, eng 22069, no abstract 07037
# 0131 data/pubmed19n0131.xml.gz: recs 30000, eng 25431, no abstract 07584
# 0132 data/pubmed19n0132.xml.gz: recs 30000, eng 25383, no abstract 06824
# 0133 data/pubmed19n0133.xml.gz: recs 30000, eng 22754, no abstract 06182
# 0134 data/pubmed19n0134.xml.gz: recs 30000, eng 23417, no abstract 06404
# 0135 data/pubmed19n0135.xml.gz: recs 30000, eng 22051, no abstract 06420
# 0136 data/pubmed19n0136.xml.gz: recs 30000, eng 19320, no abstract 09553
# 0137 data/pubmed19n0137.xml.gz: recs 30000, eng 23444, no abstract 22281
# 0138 data/pubmed19n0138.xml.gz: recs 30000, eng 22034, no abstract 20985
# 0139 data/pubmed19n0139.xml.gz: recs 30000, eng 20850, no abstract 20269
# 0140 data/pubmed19n0140.xml.gz: recs 30000, eng 19496, no abstract 17966
# 0141 data/pubmed19n0141.xml.gz: recs 30000, eng 13340, no abstract 12718
# 0142 data/pubmed19n0142.xml.gz: recs 30000, eng 16558, no abstract 15626
# 0143 data/pubmed19n0143.xml.gz: recs 30000, eng 19163, no abstract 17800
# 0144 data/pubmed19n0144.xml.gz: recs 30000, eng 20577, no abstract 18485
# 0145 data/pubmed19n0145.xml.gz: recs 30000, eng 23185, no abstract 20908
# 0146 data/pubmed19n0146.xml.gz: recs 30000, eng 20524, no abstract 19390
# 0147 data/pubmed19n0147.xml.gz: recs 30000, eng 20086, no abstract 19487
# 0148 data/pubmed19n0148.xml.gz: recs 30000, eng 15656, no abstract 14773
# 0149 data/pubmed19n0149.xml.gz: recs 30000, eng 14918, no abstract 14557
# 0150 data/pubmed19n0150.xml.gz: recs 30000, eng 19610, no abstract 18578
# 0151 data/pubmed19n0151.xml.gz: recs 30000, eng 18891, no abstract 17489
# 0152 data/pubmed19n0152.xml.gz: recs 30000, eng 20594, no abstract 19081
# 0153 data/pubmed19n0153.xml.gz: recs 30000, eng 19975, no abstract 18535
# 0154 data/pubmed19n0154.xml.gz: recs 30000, eng 18570, no abstract 17293
# 0155 data/pubmed19n0155.xml.gz: recs 30000, eng 13732, no abstract 13220
# 0156 data/pubmed19n0156.xml.gz: recs 30000, eng 21186, no abstract 20403
# 0157 data/pubmed19n0157.xml.gz: recs 30000, eng 21401, no abstract 20445
# 0158 data/pubmed19n0158.xml.gz: recs 30000, eng 20192, no abstract 19436
# 0159 data/pubmed19n0159.xml.gz: recs 30000, eng 13482, no abstract 13010
# 0160 data/pubmed19n0160.xml.gz: recs 30000, eng 20993, no abstract 20248
# 0161 data/pubmed19n0161.xml.gz: recs 30000, eng 20833, no abstract 19976
# 0162 data/pubmed19n0162.xml.gz: recs 30000, eng 16735, no abstract 15968
# 0163 data/pubmed19n0163.xml.gz: recs 30000, eng 16341, no abstract 15331
# 0164 data/pubmed19n0164.xml.gz: recs 30000, eng 17747, no abstract 16674
# 0165 data/pubmed19n0165.xml.gz: recs 30000, eng 18248, no abstract 17139
# 0166 data/pubmed19n0166.xml.gz: recs 30000, eng 17780, no abstract 16434
# 0167 data/pubmed19n0167.xml.gz: recs 30000, eng 20747, no abstract 19895
# 0168 data/pubmed19n0168.xml.gz: recs 30000, eng 19427, no abstract 18676
# 0169 data/pubmed19n0169.xml.gz: recs 30000, eng 19176, no abstract 18412
# 0170 data/pubmed19n0170.xml.gz: recs 30000, eng 18029, no abstract 17307
# 0171 data/pubmed19n0171.xml.gz: recs 30000, eng 13210, no abstract 12751
# 0172 data/pubmed19n0172.xml.gz: recs 30000, eng 14816, no abstract 14486
# 0173 data/pubmed19n0173.xml.gz: recs 30000, eng 13861, no abstract 13741
# 0174 data/pubmed19n0174.xml.gz: recs 30000, eng 18511, no abstract 18482
# 0175 data/pubmed19n0175.xml.gz: recs 30000, eng 18336, no abstract 17606
# 0176 data/pubmed19n0176.xml.gz: recs 30000, eng 16572, no abstract 15760
# 0177 data/pubmed19n0177.xml.gz: recs 30000, eng 17547, no abstract 16682
# 0178 data/pubmed19n0178.xml.gz: recs 30000, eng 18095, no abstract 17414
# 0179 data/pubmed19n0179.xml.gz: recs 30000, eng 09809, no abstract 09612
# 0180 data/pubmed19n0180.xml.gz: recs 30000, eng 16109, no abstract 15385
# 0181 data/pubmed19n0181.xml.gz: recs 30000, eng 19669, no abstract 18828
# 0182 data/pubmed19n0182.xml.gz: recs 30000, eng 17796, no abstract 17036
# 0183 data/pubmed19n0183.xml.gz: recs 30000, eng 13397, no abstract 12701
# 0184 data/pubmed19n0184.xml.gz: recs 30000, eng 16805, no abstract 16153
# 0185 data/pubmed19n0185.xml.gz: recs 30000, eng 18171, no abstract 17484
# 0186 data/pubmed19n0186.xml.gz: recs 30000, eng 07259, no abstract 07020
# 0187 data/pubmed19n0187.xml.gz: recs 30000, eng 07757, no abstract 07436
# 0188 data/pubmed19n0188.xml.gz: recs 30000, eng 24680, no abstract 23711
# 0189 data/pubmed19n0189.xml.gz: recs 30000, eng 18403, no abstract 17678
# 0190 data/pubmed19n0190.xml.gz: recs 30000, eng 13895, no abstract 13497
# 0191 data/pubmed19n0191.xml.gz: recs 30000, eng 06364, no abstract 06275
# 0192 data/pubmed19n0192.xml.gz: recs 30000, eng 22860, no abstract 21611
# 0193 data/pubmed19n0193.xml.gz: recs 30000, eng 19936, no abstract 19244
# 0194 data/pubmed19n0194.xml.gz: recs 30000, eng 16844, no abstract 16341
# 0195 data/pubmed19n0195.xml.gz: recs 30000, eng 09839, no abstract 09594
# 0196 data/pubmed19n0196.xml.gz: recs 30000, eng 14471, no abstract 14098
# 0197 data/pubmed19n0197.xml.gz: recs 30000, eng 21299, no abstract 20466
# 0198 data/pubmed19n0198.xml.gz: recs 30000, eng 20021, no abstract 19338
# 0199 data/pubmed19n0199.xml.gz: recs 30000, eng 07503, no abstract 07309
# 0200 data/pubmed19n0200.xml.gz: recs 30000, eng 16469, no abstract 15754
# 0201 data/pubmed19n0201.xml.gz: recs 30000, eng 24315, no abstract 23293
# 0202 data/pubmed19n0202.xml.gz: recs 30000, eng 21524, no abstract 17057
# 0203 data/pubmed19n0203.xml.gz: recs 30000, eng 24747, no abstract 10579
# 0204 data/pubmed19n0204.xml.gz: recs 30000, eng 25591, no abstract 10770
# 0205 data/pubmed19n0205.xml.gz: recs 30000, eng 24153, no abstract 08294
# 0206 data/pubmed19n0206.xml.gz: recs 30000, eng 24857, no abstract 05302
# 0207 data/pubmed19n0207.xml.gz: recs 30000, eng 19372, no abstract 06222
# 0208 data/pubmed19n0208.xml.gz: recs 30000, eng 24344, no abstract 08880
# 0209 data/pubmed19n0209.xml.gz: recs 30000, eng 25137, no abstract 08199
# 0210 data/pubmed19n0210.xml.gz: recs 30000, eng 25199, no abstract 04406
# 0211 data/pubmed19n0211.xml.gz: recs 30000, eng 23238, no abstract 07657
# 0212 data/pubmed19n0212.xml.gz: recs 30000, eng 22818, no abstract 07456
# 0213 data/pubmed19n0213.xml.gz: recs 30000, eng 22387, no abstract 08180
# 0214 data/pubmed19n0214.xml.gz: recs 30000, eng 22992, no abstract 07917
# 0215 data/pubmed19n0215.xml.gz: recs 30000, eng 20565, no abstract 06796
# 0216 data/pubmed19n0216.xml.gz: recs 30000, eng 21652, no abstract 06391
# 0217 data/pubmed19n0217.xml.gz: recs 30000, eng 18262, no abstract 06269
# 0218 data/pubmed19n0218.xml.gz: recs 30000, eng 20155, no abstract 13150
# 0219 data/pubmed19n0219.xml.gz: recs 30000, eng 20980, no abstract 11277
# 0220 data/pubmed19n0220.xml.gz: recs 30000, eng 22713, no abstract 06218
# 0221 data/pubmed19n0221.xml.gz: recs 30000, eng 19952, no abstract 06322
# 0222 data/pubmed19n0222.xml.gz: recs 30000, eng 19127, no abstract 06408
# 0223 data/pubmed19n0223.xml.gz: recs 30000, eng 24369, no abstract 06814
# 0224 data/pubmed19n0224.xml.gz: recs 30000, eng 24016, no abstract 06908
# 0225 data/pubmed19n0225.xml.gz: recs 30000, eng 21868, no abstract 09847
# 0226 data/pubmed19n0226.xml.gz: recs 30000, eng 23604, no abstract 10482
# 0227 data/pubmed19n0227.xml.gz: recs 30000, eng 24788, no abstract 09348
# 0228 data/pubmed19n0228.xml.gz: recs 30000, eng 23061, no abstract 07929
# 0229 data/pubmed19n0229.xml.gz: recs 30000, eng 22786, no abstract 08550
# 0230 data/pubmed19n0230.xml.gz: recs 30000, eng 19191, no abstract 16192
# 0231 data/pubmed19n0231.xml.gz: recs 30000, eng 21316, no abstract 12534
# 0232 data/pubmed19n0232.xml.gz: recs 30000, eng 21973, no abstract 09425
# 0233 data/pubmed19n0233.xml.gz: recs 30000, eng 22039, no abstract 09733
# 0234 data/pubmed19n0234.xml.gz: recs 30000, eng 22044, no abstract 10400
# 0235 data/pubmed19n0235.xml.gz: recs 30000, eng 24563, no abstract 10136
# 0236 data/pubmed19n0236.xml.gz: recs 30000, eng 22467, no abstract 09800
# 0237 data/pubmed19n0237.xml.gz: recs 30000, eng 21919, no abstract 09733
# 0238 data/pubmed19n0238.xml.gz: recs 30000, eng 18963, no abstract 08816
# 0239 data/pubmed19n0239.xml.gz: recs 30000, eng 20291, no abstract 08936
# 0240 data/pubmed19n0240.xml.gz: recs 30000, eng 21682, no abstract 09109
# 0241 data/pubmed19n0241.xml.gz: recs 30000, eng 21234, no abstract 09475
# 0242 data/pubmed19n0242.xml.gz: recs 30000, eng 21329, no abstract 10050
# 0243 data/pubmed19n0243.xml.gz: recs 30000, eng 19588, no abstract 08889
# 0244 data/pubmed19n0244.xml.gz: recs 30000, eng 18123, no abstract 09205
# 0245 data/pubmed19n0245.xml.gz: recs 30000, eng 24418, no abstract 11193
# 0246 data/pubmed19n0246.xml.gz: recs 30000, eng 21338, no abstract 09854
# 0247 data/pubmed19n0247.xml.gz: recs 30000, eng 21994, no abstract 08937
# 0248 data/pubmed19n0248.xml.gz: recs 30000, eng 19946, no abstract 07870
# 0249 data/pubmed19n0249.xml.gz: recs 30000, eng 25136, no abstract 06071
# 0250 data/pubmed19n0250.xml.gz: recs 30000, eng 27269, no abstract 03911
# 0251 data/pubmed19n0251.xml.gz: recs 30000, eng 27287, no abstract 04569
# 0252 data/pubmed19n0252.xml.gz: recs 30000, eng 26111, no abstract 05797
# 0253 data/pubmed19n0253.xml.gz: recs 30000, eng 26620, no abstract 05798
# 0254 data/pubmed19n0254.xml.gz: recs 30000, eng 26386, no abstract 06323
# 0255 data/pubmed19n0255.xml.gz: recs 30000, eng 25707, no abstract 06416
# 0256 data/pubmed19n0256.xml.gz: recs 30000, eng 26774, no abstract 04987
# 0257 data/pubmed19n0257.xml.gz: recs 30000, eng 25427, no abstract 06110
# 0258 data/pubmed19n0258.xml.gz: recs 30000, eng 26022, no abstract 05854
# 0259 data/pubmed19n0259.xml.gz: recs 30000, eng 25681, no abstract 06311
# 0260 data/pubmed19n0260.xml.gz: recs 30000, eng 25276, no abstract 06058
# 0261 data/pubmed19n0261.xml.gz: recs 30000, eng 25449, no abstract 06211
# 0262 data/pubmed19n0262.xml.gz: recs 30000, eng 26118, no abstract 06554
# 0263 data/pubmed19n0263.xml.gz: recs 30000, eng 26778, no abstract 06468
# 0264 data/pubmed19n0264.xml.gz: recs 30000, eng 25668, no abstract 05899
# 0265 data/pubmed19n0265.xml.gz: recs 30000, eng 25826, no abstract 06139
# 0266 data/pubmed19n0266.xml.gz: recs 30000, eng 24634, no abstract 06002
# 0267 data/pubmed19n0267.xml.gz: recs 30000, eng 25764, no abstract 06124
# 0268 data/pubmed19n0268.xml.gz: recs 30000, eng 25131, no abstract 05821
# 0269 data/pubmed19n0269.xml.gz: recs 30000, eng 25592, no abstract 06640
# 0270 data/pubmed19n0270.xml.gz: recs 30000, eng 25633, no abstract 06465
# 0271 data/pubmed19n0271.xml.gz: recs 30000, eng 25344, no abstract 06208
# 0272 data/pubmed19n0272.xml.gz: recs 30000, eng 25687, no abstract 06051
# 0273 data/pubmed19n0273.xml.gz: recs 30000, eng 25232, no abstract 06048
# 0274 data/pubmed19n0274.xml.gz: recs 30000, eng 25706, no abstract 05811
# 0275 data/pubmed19n0275.xml.gz: recs 30000, eng 25545, no abstract 06245
# 0276 data/pubmed19n0276.xml.gz: recs 30000, eng 25657, no abstract 05933
# 0277 data/pubmed19n0277.xml.gz: recs 30000, eng 24849, no abstract 05986
# 0278 data/pubmed19n0278.xml.gz: recs 30000, eng 25846, no abstract 06863
# 0279 data/pubmed19n0279.xml.gz: recs 30000, eng 26776, no abstract 04457
# 0280 data/pubmed19n0280.xml.gz: recs 30000, eng 27686, no abstract 06952
# 0281 data/pubmed19n0281.xml.gz: recs 30000, eng 27647, no abstract 06785
# 0282 data/pubmed19n0282.xml.gz: recs 30000, eng 26135, no abstract 06693
# 0283 data/pubmed19n0283.xml.gz: recs 30000, eng 25829, no abstract 06723
# 0284 data/pubmed19n0284.xml.gz: recs 30000, eng 26120, no abstract 06514
# 0285 data/pubmed19n0285.xml.gz: recs 30000, eng 26002, no abstract 05132
# 0286 data/pubmed19n0286.xml.gz: recs 30000, eng 27229, no abstract 06007
# 0287 data/pubmed19n0287.xml.gz: recs 30000, eng 28334, no abstract 06489
# 0288 data/pubmed19n0288.xml.gz: recs 30000, eng 25932, no abstract 06116
# 0289 data/pubmed19n0289.xml.gz: recs 30000, eng 24493, no abstract 06183
# 0290 data/pubmed19n0290.xml.gz: recs 30000, eng 24661, no abstract 05948
# 0291 data/pubmed19n0291.xml.gz: recs 30000, eng 24966, no abstract 04478
# 0292 data/pubmed19n0292.xml.gz: recs 30000, eng 26389, no abstract 05805
# 0293 data/pubmed19n0293.xml.gz: recs 30000, eng 28251, no abstract 05533
# 0294 data/pubmed19n0294.xml.gz: recs 30000, eng 27627, no abstract 05151
# 0295 data/pubmed19n0295.xml.gz: recs 30000, eng 29013, no abstract 05497
# 0296 data/pubmed19n0296.xml.gz: recs 30000, eng 29214, no abstract 05629
# 0297 data/pubmed19n0297.xml.gz: recs 30000, eng 26677, no abstract 05764
# 0298 data/pubmed19n0298.xml.gz: recs 30000, eng 24686, no abstract 05595
# 0299 data/pubmed19n0299.xml.gz: recs 30000, eng 25513, no abstract 05365
# 0300 data/pubmed19n0300.xml.gz: recs 30000, eng 25599, no abstract 05544
# 0301 data/pubmed19n0301.xml.gz: recs 30000, eng 26175, no abstract 05684
# 0302 data/pubmed19n0302.xml.gz: recs 30000, eng 25690, no abstract 05329
# 0303 data/pubmed19n0303.xml.gz: recs 30000, eng 27336, no abstract 06492
# 0304 data/pubmed19n0304.xml.gz: recs 30000, eng 26459, no abstract 05680
# 0305 data/pubmed19n0305.xml.gz: recs 30000, eng 26373, no abstract 05634
# 0306 data/pubmed19n0306.xml.gz: recs 30000, eng 26867, no abstract 05231
# 0307 data/pubmed19n0307.xml.gz: recs 30000, eng 26566, no abstract 05842
# 0308 data/pubmed19n0308.xml.gz: recs 30000, eng 25306, no abstract 05836
# 0309 data/pubmed19n0309.xml.gz: recs 30000, eng 25962, no abstract 05555
# 0310 data/pubmed19n0310.xml.gz: recs 30000, eng 27564, no abstract 06247
# 0311 data/pubmed19n0311.xml.gz: recs 30000, eng 25518, no abstract 05652
# 0312 data/pubmed19n0312.xml.gz: recs 30000, eng 26000, no abstract 05830
# 0313 data/pubmed19n0313.xml.gz: recs 30000, eng 26137, no abstract 05941
# 0314 data/pubmed19n0314.xml.gz: recs 30000, eng 25080, no abstract 05643
# 0315 data/pubmed19n0315.xml.gz: recs 30000, eng 25298, no abstract 05405
# 0316 data/pubmed19n0316.xml.gz: recs 30000, eng 26086, no abstract 05644
# 0317 data/pubmed19n0317.xml.gz: recs 30000, eng 26611, no abstract 06148
# 0318 data/pubmed19n0318.xml.gz: recs 30000, eng 25444, no abstract 05540
# 0319 data/pubmed19n0319.xml.gz: recs 30000, eng 25964, no abstract 05316
# 0320 data/pubmed19n0320.xml.gz: recs 30000, eng 26018, no abstract 05838
# 0321 data/pubmed19n0321.xml.gz: recs 30000, eng 27335, no abstract 05563
# 0322 data/pubmed19n0322.xml.gz: recs 30000, eng 27413, no abstract 05557
# 0323 data/pubmed19n0323.xml.gz: recs 30000, eng 26209, no abstract 05404
# 0324 data/pubmed19n0324.xml.gz: recs 30000, eng 24977, no abstract 05311
# 0325 data/pubmed19n0325.xml.gz: recs 30000, eng 26519, no abstract 05506
# 0326 data/pubmed19n0326.xml.gz: recs 30000, eng 26258, no abstract 05208
# 0327 data/pubmed19n0327.xml.gz: recs 30000, eng 26121, no abstract 05384
# 0328 data/pubmed19n0328.xml.gz: recs 30000, eng 27914, no abstract 15323
# 0329 data/pubmed19n0329.xml.gz: recs 30000, eng 27827, no abstract 13422
# 0330 data/pubmed19n0330.xml.gz: recs 30000, eng 29431, no abstract 27178
# 0331 data/pubmed19n0331.xml.gz: recs 30000, eng 29369, no abstract 24461
# 0332 data/pubmed19n0332.xml.gz: recs 30000, eng 29321, no abstract 24501
# 0333 data/pubmed19n0333.xml.gz: recs 30000, eng 28938, no abstract 22120
# 0334 data/pubmed19n0334.xml.gz: recs 30000, eng 26757, no abstract 08998
# 0335 data/pubmed19n0335.xml.gz: recs 30000, eng 28546, no abstract 13869
# 0336 data/pubmed19n0336.xml.gz: recs 30000, eng 29991, no abstract 19836
# 0337 data/pubmed19n0337.xml.gz: recs 30000, eng 29993, no abstract 19113
# 0338 data/pubmed19n0338.xml.gz: recs 30000, eng 27987, no abstract 09108
# 0339 data/pubmed19n0339.xml.gz: recs 30000, eng 27520, no abstract 09468
# 0340 data/pubmed19n0340.xml.gz: recs 30000, eng 29995, no abstract 25933
# 0341 data/pubmed19n0341.xml.gz: recs 30000, eng 30000, no abstract 24446
# 0342 data/pubmed19n0342.xml.gz: recs 30000, eng 28738, no abstract 17997
# 0343 data/pubmed19n0343.xml.gz: recs 30000, eng 27321, no abstract 07989
# 0344 data/pubmed19n0344.xml.gz: recs 30000, eng 26577, no abstract 05504
# 0345 data/pubmed19n0345.xml.gz: recs 30000, eng 26679, no abstract 05036
# 0346 data/pubmed19n0346.xml.gz: recs 30000, eng 26143, no abstract 05288
# 0347 data/pubmed19n0347.xml.gz: recs 30000, eng 27288, no abstract 05782
# 0348 data/pubmed19n0348.xml.gz: recs 30000, eng 27114, no abstract 05668
# 0349 data/pubmed19n0349.xml.gz: recs 30000, eng 27279, no abstract 07089
# 0350 data/pubmed19n0350.xml.gz: recs 30000, eng 27106, no abstract 05816
# 0351 data/pubmed19n0351.xml.gz: recs 30000, eng 26672, no abstract 05743
# 0352 data/pubmed19n0352.xml.gz: recs 30000, eng 27262, no abstract 06788
# 0353 data/pubmed19n0353.xml.gz: recs 30000, eng 26982, no abstract 05883
# 0354 data/pubmed19n0354.xml.gz: recs 30000, eng 26640, no abstract 05696
# 0355 data/pubmed19n0355.xml.gz: recs 30000, eng 27918, no abstract 05674
# 0356 data/pubmed19n0356.xml.gz: recs 30000, eng 26920, no abstract 06113
# 0357 data/pubmed19n0357.xml.gz: recs 30000, eng 26746, no abstract 05480
# 0358 data/pubmed19n0358.xml.gz: recs 30000, eng 27087, no abstract 06152
# 0359 data/pubmed19n0359.xml.gz: recs 30000, eng 27361, no abstract 06199
# 0360 data/pubmed19n0360.xml.gz: recs 30000, eng 26571, no abstract 05263
# 0361 data/pubmed19n0361.xml.gz: recs 30000, eng 26132, no abstract 05747
# 0362 data/pubmed19n0362.xml.gz: recs 30000, eng 26360, no abstract 05698
# 0363 data/pubmed19n0363.xml.gz: recs 30000, eng 27137, no abstract 05513
# 0364 data/pubmed19n0364.xml.gz: recs 30000, eng 27515, no abstract 06106
# 0365 data/pubmed19n0365.xml.gz: recs 30000, eng 26608, no abstract 05670
# 0366 data/pubmed19n0366.xml.gz: recs 30000, eng 26874, no abstract 06378
# 0367 data/pubmed19n0367.xml.gz: recs 30000, eng 27080, no abstract 05264
# 0368 data/pubmed19n0368.xml.gz: recs 30000, eng 27537, no abstract 05917
# 0369 data/pubmed19n0369.xml.gz: recs 30000, eng 27597, no abstract 05629
# 0370 data/pubmed19n0370.xml.gz: recs 30000, eng 27894, no abstract 06723
# 0371 data/pubmed19n0371.xml.gz: recs 30000, eng 25123, no abstract 06612
# 0372 data/pubmed19n0372.xml.gz: recs 30000, eng 26959, no abstract 05770
# 0373 data/pubmed19n0373.xml.gz: recs 30000, eng 27012, no abstract 06316
# 0374 data/pubmed19n0374.xml.gz: recs 30000, eng 27800, no abstract 05082
# 0375 data/pubmed19n0375.xml.gz: recs 30000, eng 26987, no abstract 05195
# 0376 data/pubmed19n0376.xml.gz: recs 30000, eng 27647, no abstract 09997
# 0377 data/pubmed19n0377.xml.gz: recs 30000, eng 27056, no abstract 05297
# 0378 data/pubmed19n0378.xml.gz: recs 30000, eng 26972, no abstract 05650
# 0379 data/pubmed19n0379.xml.gz: recs 30000, eng 26918, no abstract 05193
# 0380 data/pubmed19n0380.xml.gz: recs 30000, eng 26647, no abstract 05464
# 0381 data/pubmed19n0381.xml.gz: recs 30000, eng 26412, no abstract 04868
# 0382 data/pubmed19n0382.xml.gz: recs 30000, eng 27489, no abstract 04867
# 0383 data/pubmed19n0383.xml.gz: recs 30000, eng 26876, no abstract 05664
# 0384 data/pubmed19n0384.xml.gz: recs 30000, eng 19831, no abstract 13152
# 0385 data/pubmed19n0385.xml.gz: recs 30000, eng 22231, no abstract 19830
# 0386 data/pubmed19n0386.xml.gz: recs 30000, eng 27985, no abstract 08861
# 0387 data/pubmed19n0387.xml.gz: recs 30000, eng 27292, no abstract 05186
# 0388 data/pubmed19n0388.xml.gz: recs 30000, eng 28697, no abstract 05108
# 0389 data/pubmed19n0389.xml.gz: recs 30000, eng 24229, no abstract 05390
# 0390 data/pubmed19n0390.xml.gz: recs 30000, eng 26329, no abstract 05440
# 0391 data/pubmed19n0391.xml.gz: recs 30000, eng 26476, no abstract 05565
# 0392 data/pubmed19n0392.xml.gz: recs 30000, eng 26254, no abstract 05717
# 0393 data/pubmed19n0393.xml.gz: recs 30000, eng 27489, no abstract 06719
# 0394 data/pubmed19n0394.xml.gz: recs 30000, eng 25977, no abstract 06640
# 0395 data/pubmed19n0395.xml.gz: recs 30000, eng 26861, no abstract 08552
# 0396 data/pubmed19n0396.xml.gz: recs 30000, eng 26998, no abstract 06408
# 0397 data/pubmed19n0397.xml.gz: recs 30000, eng 27036, no abstract 06987
# 0398 data/pubmed19n0398.xml.gz: recs 30000, eng 26595, no abstract 05234
# 0399 data/pubmed19n0399.xml.gz: recs 30000, eng 26490, no abstract 05720
# 0400 data/pubmed19n0400.xml.gz: recs 30000, eng 27345, no abstract 04879
# 0401 data/pubmed19n0401.xml.gz: recs 30000, eng 27095, no abstract 05916
# 0402 data/pubmed19n0402.xml.gz: recs 30000, eng 26676, no abstract 05927
# 0403 data/pubmed19n0403.xml.gz: recs 30000, eng 26659, no abstract 05146
# 0404 data/pubmed19n0404.xml.gz: recs 30000, eng 23662, no abstract 14267
# 0405 data/pubmed19n0405.xml.gz: recs 30000, eng 25953, no abstract 10715
# 0406 data/pubmed19n0406.xml.gz: recs 30000, eng 27228, no abstract 05030
# 0407 data/pubmed19n0407.xml.gz: recs 30000, eng 27046, no abstract 05740
# 0408 data/pubmed19n0408.xml.gz: recs 30000, eng 27076, no abstract 05172
# 0409 data/pubmed19n0409.xml.gz: recs 30000, eng 26718, no abstract 05588
# 0410 data/pubmed19n0410.xml.gz: recs 30000, eng 26138, no abstract 05502
# 0411 data/pubmed19n0411.xml.gz: recs 30000, eng 24864, no abstract 04595
# 0412 data/pubmed19n0412.xml.gz: recs 30000, eng 24767, no abstract 04788
# 0413 data/pubmed19n0413.xml.gz: recs 30000, eng 26259, no abstract 05548
# 0414 data/pubmed19n0414.xml.gz: recs 30000, eng 26764, no abstract 04995
# 0415 data/pubmed19n0415.xml.gz: recs 30000, eng 27096, no abstract 05019
# 0416 data/pubmed19n0416.xml.gz: recs 30000, eng 26149, no abstract 04839
# 0417 data/pubmed19n0417.xml.gz: recs 30000, eng 26724, no abstract 05244
# 0418 data/pubmed19n0418.xml.gz: recs 30000, eng 27153, no abstract 05171
# 0419 data/pubmed19n0419.xml.gz: recs 30000, eng 27044, no abstract 04824
# 0420 data/pubmed19n0420.xml.gz: recs 30000, eng 26647, no abstract 05316
# 0421 data/pubmed19n0421.xml.gz: recs 30000, eng 27126, no abstract 05465
# 0422 data/pubmed19n0422.xml.gz: recs 30000, eng 25613, no abstract 04390
# 0423 data/pubmed19n0423.xml.gz: recs 30000, eng 26103, no abstract 04754
# 0424 data/pubmed19n0424.xml.gz: recs 30000, eng 24269, no abstract 07263
# 0425 data/pubmed19n0425.xml.gz: recs 30000, eng 15157, no abstract 15087
# 0426 data/pubmed19n0426.xml.gz: recs 30000, eng 14098, no abstract 14025
# 0427 data/pubmed19n0427.xml.gz: recs 30000, eng 14129, no abstract 13996
# 0428 data/pubmed19n0428.xml.gz: recs 30000, eng 11251, no abstract 11183
# 0429 data/pubmed19n0429.xml.gz: recs 30000, eng 14692, no abstract 13671
# 0430 data/pubmed19n0430.xml.gz: recs 30000, eng 12638, no abstract 12567
# 0431 data/pubmed19n0431.xml.gz: recs 30000, eng 12258, no abstract 12147
# 0432 data/pubmed19n0432.xml.gz: recs 30000, eng 15738, no abstract 15616
# 0433 data/pubmed19n0433.xml.gz: recs 30000, eng 13811, no abstract 13702
# 0434 data/pubmed19n0434.xml.gz: recs 30000, eng 14966, no abstract 14830
# 0435 data/pubmed19n0435.xml.gz: recs 30000, eng 12483, no abstract 12375
# 0436 data/pubmed19n0436.xml.gz: recs 30000, eng 12115, no abstract 12022
# 0437 data/pubmed19n0437.xml.gz: recs 30000, eng 15481, no abstract 15298
# 0438 data/pubmed19n0438.xml.gz: recs 30000, eng 11923, no abstract 11818
# 0439 data/pubmed19n0439.xml.gz: recs 30000, eng 15128, no abstract 14958
# 0440 data/pubmed19n0440.xml.gz: recs 30000, eng 12587, no abstract 12428
# 0441 data/pubmed19n0441.xml.gz: recs 30000, eng 16338, no abstract 16111
# 0442 data/pubmed19n0442.xml.gz: recs 30000, eng 14117, no abstract 14026
# 0443 data/pubmed19n0443.xml.gz: recs 30000, eng 12483, no abstract 12339
# 0444 data/pubmed19n0444.xml.gz: recs 30000, eng 14055, no abstract 13938
# 0445 data/pubmed19n0445.xml.gz: recs 30000, eng 14051, no abstract 13843
# 0446 data/pubmed19n0446.xml.gz: recs 30000, eng 16040, no abstract 15785
# 0447 data/pubmed19n0447.xml.gz: recs 30000, eng 14351, no abstract 14066
# 0448 data/pubmed19n0448.xml.gz: recs 30000, eng 15063, no abstract 12358
# 0449 data/pubmed19n0449.xml.gz: recs 30000, eng 14141, no abstract 13825
# 0450 data/pubmed19n0450.xml.gz: recs 30000, eng 12777, no abstract 12502
# 0451 data/pubmed19n0451.xml.gz: recs 30000, eng 14026, no abstract 13731
# 0452 data/pubmed19n0452.xml.gz: recs 30000, eng 14743, no abstract 14493
# 0453 data/pubmed19n0453.xml.gz: recs 30000, eng 14946, no abstract 14717
# 0454 data/pubmed19n0454.xml.gz: recs 30000, eng 14767, no abstract 14440
# 0455 data/pubmed19n0455.xml.gz: recs 30000, eng 15016, no abstract 14624
# 0456 data/pubmed19n0456.xml.gz: recs 30000, eng 13139, no abstract 12783
# 0457 data/pubmed19n0457.xml.gz: recs 30000, eng 14922, no abstract 14466
# 0458 data/pubmed19n0458.xml.gz: recs 30000, eng 14891, no abstract 14434
# 0459 data/pubmed19n0459.xml.gz: recs 30000, eng 14848, no abstract 14429
# 0460 data/pubmed19n0460.xml.gz: recs 30000, eng 17791, no abstract 17185
# 0461 data/pubmed19n0461.xml.gz: recs 30000, eng 14993, no abstract 14487
# 0462 data/pubmed19n0462.xml.gz: recs 30000, eng 14238, no abstract 13833
# 0463 data/pubmed19n0463.xml.gz: recs 30000, eng 14754, no abstract 14345
# 0464 data/pubmed19n0464.xml.gz: recs 30000, eng 15103, no abstract 14605
# 0465 data/pubmed19n0465.xml.gz: recs 30000, eng 18559, no abstract 17965
# 0466 data/pubmed19n0466.xml.gz: recs 30000, eng 16500, no abstract 15979
# 0467 data/pubmed19n0467.xml.gz: recs 30000, eng 17290, no abstract 16824
# 0468 data/pubmed19n0468.xml.gz: recs 30000, eng 16484, no abstract 16101
# 0469 data/pubmed19n0469.xml.gz: recs 30000, eng 14105, no abstract 13751
# 0470 data/pubmed19n0470.xml.gz: recs 30000, eng 13518, no abstract 13128
# 0471 data/pubmed19n0471.xml.gz: recs 30000, eng 11489, no abstract 11430
# 0472 data/pubmed19n0472.xml.gz: recs 30000, eng 15378, no abstract 15124
# 0473 data/pubmed19n0473.xml.gz: recs 30000, eng 14646, no abstract 14389
# 0474 data/pubmed19n0474.xml.gz: recs 30000, eng 12518, no abstract 12174
# 0475 data/pubmed19n0475.xml.gz: recs 30000, eng 22311, no abstract 07978
# 0476 data/pubmed19n0476.xml.gz: recs 30000, eng 27018, no abstract 05038
# 0477 data/pubmed19n0477.xml.gz: recs 30000, eng 26636, no abstract 05141
# 0478 data/pubmed19n0478.xml.gz: recs 30000, eng 27204, no abstract 05222
# 0479 data/pubmed19n0479.xml.gz: recs 30000, eng 26859, no abstract 04913
# 0480 data/pubmed19n0480.xml.gz: recs 30000, eng 26653, no abstract 04970
# 0481 data/pubmed19n0481.xml.gz: recs 30000, eng 26659, no abstract 05472
# 0482 data/pubmed19n0482.xml.gz: recs 30000, eng 27236, no abstract 04956
# 0483 data/pubmed19n0483.xml.gz: recs 30000, eng 17166, no abstract 14003
# 0484 data/pubmed19n0484.xml.gz: recs 30000, eng 14250, no abstract 14155
# 0485 data/pubmed19n0485.xml.gz: recs 30000, eng 13974, no abstract 13898
# 0486 data/pubmed19n0486.xml.gz: recs 30000, eng 14801, no abstract 13313
# 0487 data/pubmed19n0487.xml.gz: recs 30000, eng 17093, no abstract 16981
# 0488 data/pubmed19n0488.xml.gz: recs 30000, eng 13554, no abstract 13486
# 0489 data/pubmed19n0489.xml.gz: recs 30000, eng 18939, no abstract 06684
# 0490 data/pubmed19n0490.xml.gz: recs 30000, eng 26735, no abstract 05069
# 0491 data/pubmed19n0491.xml.gz: recs 30000, eng 26524, no abstract 04693
# 0492 data/pubmed19n0492.xml.gz: recs 30000, eng 26786, no abstract 04938
# 0493 data/pubmed19n0493.xml.gz: recs 30000, eng 27365, no abstract 05002
# 0494 data/pubmed19n0494.xml.gz: recs 30000, eng 27583, no abstract 05233
# 0495 data/pubmed19n0495.xml.gz: recs 30000, eng 26359, no abstract 04696
# 0496 data/pubmed19n0496.xml.gz: recs 30000, eng 26961, no abstract 04879
# 0497 data/pubmed19n0497.xml.gz: recs 30000, eng 26937, no abstract 05193
# 0498 data/pubmed19n0498.xml.gz: recs 30000, eng 28045, no abstract 04525
# 0499 data/pubmed19n0499.xml.gz: recs 30000, eng 27818, no abstract 04680
# 0500 data/pubmed19n0500.xml.gz: recs 30000, eng 27059, no abstract 05107
# 0501 data/pubmed19n0501.xml.gz: recs 30000, eng 26929, no abstract 04968
# 0502 data/pubmed19n0502.xml.gz: recs 30000, eng 25491, no abstract 07746
# 0503 data/pubmed19n0503.xml.gz: recs 30000, eng 17695, no abstract 17573
# 0504 data/pubmed19n0504.xml.gz: recs 30000, eng 18057, no abstract 09892
# 0505 data/pubmed19n0505.xml.gz: recs 30000, eng 27629, no abstract 05529
# 0506 data/pubmed19n0506.xml.gz: recs 30000, eng 26240, no abstract 05234
# 0507 data/pubmed19n0507.xml.gz: recs 30000, eng 27117, no abstract 04480
# 0508 data/pubmed19n0508.xml.gz: recs 30000, eng 26422, no abstract 04806
# 0509 data/pubmed19n0509.xml.gz: recs 30000, eng 27365, no abstract 04657
# 0510 data/pubmed19n0510.xml.gz: recs 30000, eng 25867, no abstract 04705
# 0511 data/pubmed19n0511.xml.gz: recs 30000, eng 27317, no abstract 04489
# 0512 data/pubmed19n0512.xml.gz: recs 30000, eng 26967, no abstract 04857
# 0513 data/pubmed19n0513.xml.gz: recs 30000, eng 27238, no abstract 05012
# 0514 data/pubmed19n0514.xml.gz: recs 30000, eng 25324, no abstract 04413
# 0515 data/pubmed19n0515.xml.gz: recs 30000, eng 26898, no abstract 04692
# 0516 data/pubmed19n0516.xml.gz: recs 30000, eng 26512, no abstract 04778
# 0517 data/pubmed19n0517.xml.gz: recs 30000, eng 26842, no abstract 04701
# 0518 data/pubmed19n0518.xml.gz: recs 30000, eng 27407, no abstract 04048
# 0519 data/pubmed19n0519.xml.gz: recs 30000, eng 26987, no abstract 04466
# 0520 data/pubmed19n0520.xml.gz: recs 30000, eng 27067, no abstract 04333
# 0521 data/pubmed19n0521.xml.gz: recs 30000, eng 26799, no abstract 04605
# 0522 data/pubmed19n0522.xml.gz: recs 30000, eng 27457, no abstract 06468
# 0523 data/pubmed19n0523.xml.gz: recs 30000, eng 27391, no abstract 06463
# 0524 data/pubmed19n0524.xml.gz: recs 30000, eng 27303, no abstract 04437
# 0525 data/pubmed19n0525.xml.gz: recs 30000, eng 26493, no abstract 04546
# 0526 data/pubmed19n0526.xml.gz: recs 30000, eng 27469, no abstract 04349
# 0527 data/pubmed19n0527.xml.gz: recs 30000, eng 27110, no abstract 04818
# 0528 data/pubmed19n0528.xml.gz: recs 30000, eng 27232, no abstract 04040
# 0529 data/pubmed19n0529.xml.gz: recs 30000, eng 27277, no abstract 04969
# 0530 data/pubmed19n0530.xml.gz: recs 30000, eng 26862, no abstract 04668
# 0531 data/pubmed19n0531.xml.gz: recs 30000, eng 26614, no abstract 04989
# 0532 data/pubmed19n0532.xml.gz: recs 30000, eng 27652, no abstract 04258
# 0533 data/pubmed19n0533.xml.gz: recs 30000, eng 27712, no abstract 05285
# 0534 data/pubmed19n0534.xml.gz: recs 30000, eng 26999, no abstract 04304
# 0535 data/pubmed19n0535.xml.gz: recs 30000, eng 27196, no abstract 04542
# 0536 data/pubmed19n0536.xml.gz: recs 30000, eng 27469, no abstract 04453
# 0537 data/pubmed19n0537.xml.gz: recs 30000, eng 26462, no abstract 04555
# 0538 data/pubmed19n0538.xml.gz: recs 30000, eng 27605, no abstract 07094
# 0539 data/pubmed19n0539.xml.gz: recs 30000, eng 28286, no abstract 11298
# 0540 data/pubmed19n0540.xml.gz: recs 30000, eng 27046, no abstract 04454
# 0541 data/pubmed19n0541.xml.gz: recs 30000, eng 28109, no abstract 07691
# 0542 data/pubmed19n0542.xml.gz: recs 30000, eng 28155, no abstract 03240
# 0543 data/pubmed19n0543.xml.gz: recs 30000, eng 27728, no abstract 08085
# 0544 data/pubmed19n0544.xml.gz: recs 30000, eng 27930, no abstract 10178
# 0545 data/pubmed19n0545.xml.gz: recs 30000, eng 26714, no abstract 04166
# 0546 data/pubmed19n0546.xml.gz: recs 30000, eng 27569, no abstract 05054
# 0547 data/pubmed19n0547.xml.gz: recs 30000, eng 27119, no abstract 04107
# 0548 data/pubmed19n0548.xml.gz: recs 30000, eng 27712, no abstract 04253
# 0549 data/pubmed19n0549.xml.gz: recs 30000, eng 26724, no abstract 04396
# 0550 data/pubmed19n0550.xml.gz: recs 30000, eng 27628, no abstract 04880
# 0551 data/pubmed19n0551.xml.gz: recs 30000, eng 27805, no abstract 04477
# 0552 data/pubmed19n0552.xml.gz: recs 30000, eng 27770, no abstract 07860
# 0553 data/pubmed19n0553.xml.gz: recs 30000, eng 27387, no abstract 04396
# 0554 data/pubmed19n0554.xml.gz: recs 30000, eng 27037, no abstract 04127
# 0555 data/pubmed19n0555.xml.gz: recs 30000, eng 27148, no abstract 05283
# 0556 data/pubmed19n0556.xml.gz: recs 30000, eng 27221, no abstract 04498
# 0557 data/pubmed19n0557.xml.gz: recs 30000, eng 27020, no abstract 04093
# 0558 data/pubmed19n0558.xml.gz: recs 30000, eng 27384, no abstract 04631
# 0559 data/pubmed19n0559.xml.gz: recs 30000, eng 27372, no abstract 06756
# 0560 data/pubmed19n0560.xml.gz: recs 30000, eng 28117, no abstract 06600
# 0561 data/pubmed19n0561.xml.gz: recs 30000, eng 27432, no abstract 03943
# 0562 data/pubmed19n0562.xml.gz: recs 30000, eng 27557, no abstract 04727
# 0563 data/pubmed19n0563.xml.gz: recs 30000, eng 26653, no abstract 04320
# 0564 data/pubmed19n0564.xml.gz: recs 30000, eng 27694, no abstract 04828
# 0565 data/pubmed19n0565.xml.gz: recs 30000, eng 27338, no abstract 07465
# 0566 data/pubmed19n0566.xml.gz: recs 30000, eng 27017, no abstract 04491
# 0567 data/pubmed19n0567.xml.gz: recs 30000, eng 26936, no abstract 04701
# 0568 data/pubmed19n0568.xml.gz: recs 30000, eng 27560, no abstract 04343
# 0569 data/pubmed19n0569.xml.gz: recs 30000, eng 27741, no abstract 04577
# 0570 data/pubmed19n0570.xml.gz: recs 30000, eng 27010, no abstract 04513
# 0571 data/pubmed19n0571.xml.gz: recs 30000, eng 27494, no abstract 04486
# 0572 data/pubmed19n0572.xml.gz: recs 30000, eng 26904, no abstract 06032
# 0573 data/pubmed19n0573.xml.gz: recs 30000, eng 26867, no abstract 04083
# 0574 data/pubmed19n0574.xml.gz: recs 30000, eng 27547, no abstract 04298
# 0575 data/pubmed19n0575.xml.gz: recs 30000, eng 29043, no abstract 19164
# 0576 data/pubmed19n0576.xml.gz: recs 30000, eng 29472, no abstract 20267
# 0577 data/pubmed19n0577.xml.gz: recs 30000, eng 29434, no abstract 21884
# 0578 data/pubmed19n0578.xml.gz: recs 30000, eng 29369, no abstract 21173
# 0579 data/pubmed19n0579.xml.gz: recs 30000, eng 28936, no abstract 16657
# 0580 data/pubmed19n0580.xml.gz: recs 30000, eng 27602, no abstract 04562
# 0581 data/pubmed19n0581.xml.gz: recs 30000, eng 27408, no abstract 03824
# 0582 data/pubmed19n0582.xml.gz: recs 30000, eng 26883, no abstract 04136
# 0583 data/pubmed19n0583.xml.gz: recs 30000, eng 27724, no abstract 03989
# 0584 data/pubmed19n0584.xml.gz: recs 30000, eng 28272, no abstract 11900
# 0585 data/pubmed19n0585.xml.gz: recs 30000, eng 27255, no abstract 03817
# 0586 data/pubmed19n0586.xml.gz: recs 30000, eng 27528, no abstract 03923
# 0587 data/pubmed19n0587.xml.gz: recs 30000, eng 17970, no abstract 17113
# 0588 data/pubmed19n0588.xml.gz: recs 30000, eng 19341, no abstract 16183
# 0589 data/pubmed19n0589.xml.gz: recs 30000, eng 27815, no abstract 07241
# 0590 data/pubmed19n0590.xml.gz: recs 30000, eng 27222, no abstract 05549
# 0591 data/pubmed19n0591.xml.gz: recs 30000, eng 27233, no abstract 05005
# 0592 data/pubmed19n0592.xml.gz: recs 30000, eng 27081, no abstract 03526
# 0593 data/pubmed19n0593.xml.gz: recs 30000, eng 28135, no abstract 04426
# 0594 data/pubmed19n0594.xml.gz: recs 30000, eng 27369, no abstract 04412
# 0595 data/pubmed19n0595.xml.gz: recs 30000, eng 27452, no abstract 04004
# 0596 data/pubmed19n0596.xml.gz: recs 30000, eng 26924, no abstract 04251
# 0597 data/pubmed19n0597.xml.gz: recs 30000, eng 26934, no abstract 04219
# 0598 data/pubmed19n0598.xml.gz: recs 30000, eng 27635, no abstract 04228
# 0599 data/pubmed19n0599.xml.gz: recs 30000, eng 27973, no abstract 04480
# 0600 data/pubmed19n0600.xml.gz: recs 30000, eng 27564, no abstract 04062
# 0601 data/pubmed19n0601.xml.gz: recs 30000, eng 27696, no abstract 04392
# 0602 data/pubmed19n0602.xml.gz: recs 30000, eng 27438, no abstract 04229
# 0603 data/pubmed19n0603.xml.gz: recs 30000, eng 27869, no abstract 04775
# 0604 data/pubmed19n0604.xml.gz: recs 30000, eng 27382, no abstract 04597
# 0605 data/pubmed19n0605.xml.gz: recs 30000, eng 27387, no abstract 04293
# 0606 data/pubmed19n0606.xml.gz: recs 30000, eng 28250, no abstract 11830
# 0607 data/pubmed19n0607.xml.gz: recs 30000, eng 28737, no abstract 14896
# 0608 data/pubmed19n0608.xml.gz: recs 30000, eng 27302, no abstract 04447
# 0609 data/pubmed19n0609.xml.gz: recs 30000, eng 27411, no abstract 04921
# 0610 data/pubmed19n0610.xml.gz: recs 30000, eng 24594, no abstract 08400
# 0611 data/pubmed19n0611.xml.gz: recs 30000, eng 17023, no abstract 16950
# 0612 data/pubmed19n0612.xml.gz: recs 30000, eng 19174, no abstract 16305
# 0613 data/pubmed19n0613.xml.gz: recs 30000, eng 26192, no abstract 06167
# 0614 data/pubmed19n0614.xml.gz: recs 30000, eng 28242, no abstract 03199
# 0615 data/pubmed19n0615.xml.gz: recs 30000, eng 28260, no abstract 04129
# 0616 data/pubmed19n0616.xml.gz: recs 30000, eng 27446, no abstract 04369
# 0617 data/pubmed19n0617.xml.gz: recs 30000, eng 26752, no abstract 03939
# 0618 data/pubmed19n0618.xml.gz: recs 30000, eng 26647, no abstract 04421
# 0619 data/pubmed19n0619.xml.gz: recs 30000, eng 27386, no abstract 04136
# 0620 data/pubmed19n0620.xml.gz: recs 30000, eng 27378, no abstract 04106
# 0621 data/pubmed19n0621.xml.gz: recs 30000, eng 27665, no abstract 04154
# 0622 data/pubmed19n0622.xml.gz: recs 30000, eng 27594, no abstract 04265
# 0623 data/pubmed19n0623.xml.gz: recs 30000, eng 27698, no abstract 04026
# 0624 data/pubmed19n0624.xml.gz: recs 30000, eng 28128, no abstract 06284
# 0625 data/pubmed19n0625.xml.gz: recs 30000, eng 28336, no abstract 08577
# 0626 data/pubmed19n0626.xml.gz: recs 30000, eng 27450, no abstract 03723
# 0627 data/pubmed19n0627.xml.gz: recs 30000, eng 27658, no abstract 04286
# 0628 data/pubmed19n0628.xml.gz: recs 30000, eng 27875, no abstract 04012
# 0629 data/pubmed19n0629.xml.gz: recs 30000, eng 27185, no abstract 03898
# 0630 data/pubmed19n0630.xml.gz: recs 30000, eng 27848, no abstract 04010
# 0631 data/pubmed19n0631.xml.gz: recs 30000, eng 27247, no abstract 03448
# 0632 data/pubmed19n0632.xml.gz: recs 30000, eng 27517, no abstract 04126
# 0633 data/pubmed19n0633.xml.gz: recs 30000, eng 27931, no abstract 06831
# 0634 data/pubmed19n0634.xml.gz: recs 30000, eng 27440, no abstract 04281
# 0635 data/pubmed19n0635.xml.gz: recs 30000, eng 27478, no abstract 04066
# 0636 data/pubmed19n0636.xml.gz: recs 30000, eng 28297, no abstract 04469
# 0637 data/pubmed19n0637.xml.gz: recs 30000, eng 27939, no abstract 04305
# 0638 data/pubmed19n0638.xml.gz: recs 30000, eng 27848, no abstract 04433
# 0639 data/pubmed19n0639.xml.gz: recs 30000, eng 27638, no abstract 05037
# 0640 data/pubmed19n0640.xml.gz: recs 30000, eng 27851, no abstract 04380
# 0641 data/pubmed19n0641.xml.gz: recs 30000, eng 28181, no abstract 04209
# 0642 data/pubmed19n0642.xml.gz: recs 30000, eng 27918, no abstract 04201
# 0643 data/pubmed19n0643.xml.gz: recs 30000, eng 28264, no abstract 03790
# 0644 data/pubmed19n0644.xml.gz: recs 30000, eng 26886, no abstract 03720
# 0645 data/pubmed19n0645.xml.gz: recs 30000, eng 29533, no abstract 25454
# 0646 data/pubmed19n0646.xml.gz: recs 30000, eng 28080, no abstract 04258
# 0647 data/pubmed19n0647.xml.gz: recs 30000, eng 27527, no abstract 04144
# 0648 data/pubmed19n0648.xml.gz: recs 30000, eng 27324, no abstract 04872
# 0649 data/pubmed19n0649.xml.gz: recs 30000, eng 27727, no abstract 04785
# 0650 data/pubmed19n0650.xml.gz: recs 30000, eng 27836, no abstract 04512
# 0651 data/pubmed19n0651.xml.gz: recs 30000, eng 28360, no abstract 04289
# 0652 data/pubmed19n0652.xml.gz: recs 30000, eng 27116, no abstract 04494
# 0653 data/pubmed19n0653.xml.gz: recs 30000, eng 22540, no abstract 11001
# 0654 data/pubmed19n0654.xml.gz: recs 30000, eng 21882, no abstract 21882
# 0655 data/pubmed19n0655.xml.gz: recs 30000, eng 26245, no abstract 17473
# 0656 data/pubmed19n0656.xml.gz: recs 30000, eng 27450, no abstract 17856
# 0657 data/pubmed19n0657.xml.gz: recs 30000, eng 27804, no abstract 03881
# ...
# 0992 data/pubmed19n0992.xml.gz: recs 09324, eng 09091, no abstract 00890
# 0993 data/pubmed19n0993.xml.gz: recs 14543, eng 14406, no abstract 01118
# 0994 data/pubmed19n0994.xml.gz: recs 18826, eng 18623, no abstract 01666
# 0995 data/pubmed19n0995.xml.gz: recs 05510, eng 05204, no abstract 00651
# 0996 data/pubmed19n0996.xml.gz: recs 01729, eng 01728, no abstract 00149
# 0997 data/pubmed19n0997.xml.gz: recs 14198, eng 14116, no abstract 01033
# 0998 data/pubmed19n0998.xml.gz: recs 11749, eng 11289, no abstract 01279
# 0999 data/pubmed19n0999.xml.gz: recs 22351, eng 22221, no abstract 07225
# 1000 data/pubmed19n1000.xml.gz: recs 17768, eng 17070, no abstract 01956
# 1001 data/pubmed19n1001.xml.gz: recs 20882, eng 20460, no abstract 02013
# 1002 data/pubmed19n1002.xml.gz: recs 08562, eng 08279, no abstract 00848
# 1003 data/pubmed19n1003.xml.gz: recs 01743, eng 01740, no abstract 00140
# 1004 data/pubmed19n1004.xml.gz: recs 12411, eng 12266, no abstract 01391
# 1005 data/pubmed19n1005.xml.gz: recs 30000, eng 29950, no abstract 00973
# 1006 data/pubmed19n1006.xml.gz: recs 30000, eng 29916, no abstract 02367
# 1007 data/pubmed19n1007.xml.gz: recs 28226, eng 27908, no abstract 01725
# 1008 data/pubmed19n1008.xml.gz: recs 30000, eng 29538, no abstract 02246
# 1009 data/pubmed19n1009.xml.gz: recs 03075, eng 03010, no abstract 00307
# 1010 data/pubmed19n1010.xml.gz: recs 30000, eng 29381, no abstract 03665
# 1011 data/pubmed19n1011.xml.gz: recs 01145, eng 00925, no abstract 00158
# 1012 data/pubmed19n1012.xml.gz: recs 28439, eng 28091, no abstract 02523
# 1013 data/pubmed19n1013.xml.gz: recs 27198, eng 26749, no abstract 02282
# 1014 data/pubmed19n1014.xml.gz: recs 06258, eng 06250, no abstract 00415
# 1015 data/pubmed19n1015.xml.gz: recs 14304, eng 14096, no abstract 01404
# 1016 data/pubmed19n1016.xml.gz: recs 30000, eng 29048, no abstract 04000
# 1017 data/pubmed19n1017.xml.gz: recs 11040, eng 09999, no abstract 01130
# 1018 data/pubmed19n1018.xml.gz: recs 27644, eng 26732, no abstract 02400
# 1019 data/pubmed19n1019.xml.gz: recs 30000, eng 29012, no abstract 04285
# 1020 data/pubmed19n1020.xml.gz: recs 01728, eng 01680, no abstract 00228
# 1021 data/pubmed19n1021.xml.gz: recs 30000, eng 29831, no abstract 02962
# 1022 data/pubmed19n1022.xml.gz: recs 00495, eng 00459, no abstract 00039
# 1023 data/pubmed19n1023.xml.gz: recs 10014, eng 09637, no abstract 00926
# 1024 data/pubmed19n1024.xml.gz: recs 05170, eng 05071, no abstract 00254
# 1025 data/pubmed19n1025.xml.gz: recs 11275, eng 11148, no abstract 01122
# 1026 data/pubmed19n1026.xml.gz: recs 15846, eng 15637, no abstract 01722
# 1027 data/pubmed19n1027.xml.gz: recs 24761, eng 24128, no abstract 03470
# 1028 data/pubmed19n1028.xml.gz: recs 23619, eng 23272, no abstract 03581
# 1029 data/pubmed19n1029.xml.gz: recs 23983, eng 23242, no abstract 03034
# 1030 data/pubmed19n1030.xml.gz: recs 15839, eng 15493, no abstract 01555
# 1031 data/pubmed19n1031.xml.gz: recs 03836, eng 03835, no abstract 00158
# 1032 data/pubmed19n1032.xml.gz: recs 16120, eng 15864, no abstract 01761
# 1033 data/pubmed19n1033.xml.gz: recs 30000, eng 29601, no abstract 02539
# 1034 data/pubmed19n1034.xml.gz: recs 06297, eng 05925, no abstract 00605
# 1035 data/pubmed19n1035.xml.gz: recs 24391, eng 24124, no abstract 02018
# 1036 data/pubmed19n1036.xml.gz: recs 23962, eng 23358, no abstract 01637
# 1037 data/pubmed19n1037.xml.gz: recs 30000, eng 29705, no abstract 02338
# 1038 data/pubmed19n1038.xml.gz: recs 11815, eng 11591, no abstract 01051
# 1039 data/pubmed19n1039.xml.gz: recs 25873, eng 25717, no abstract 01869
# 1040 data/pubmed19n1040.xml.gz: recs 05631, eng 05630, no abstract 00410
# 1041 data/pubmed19n1041.xml.gz: recs 16130, eng 15995, no abstract 02081
# 1042 data/pubmed19n1042.xml.gz: recs 27056, eng 26302, no abstract 02449
# 1043 data/pubmed19n1043.xml.gz: recs 20138, eng 19431, no abstract 02023
# 1044 data/pubmed19n1044.xml.gz: recs 27918, eng 27276, no abstract 02898
# 1045 data/pubmed19n1045.xml.gz: recs 25135, eng 24564, no abstract 02620
# 1046 data/pubmed19n1046.xml.gz: recs 16486, eng 16170, no abstract 01352
# 1047 data/pubmed19n1047.xml.gz: recs 05082, eng 05082, no abstract 00231
# 1048 data/pubmed19n1048.xml.gz: recs 14879, eng 14619, no abstract 01431
# 1049 data/pubmed19n1049.xml.gz: recs 30000, eng 28757, no abstract 02531
# 1050 data/pubmed19n1050.xml.gz: recs 03542, eng 03462, no abstract 00547
# 1051 data/pubmed19n1051.xml.gz: recs 30000, eng 29326, no abstract 06725
# 1052 data/pubmed19n1052.xml.gz: recs 05295, eng 05076, no abstract 01669
# 1053 data/pubmed19n1053.xml.gz: recs 24396, eng 23796, no abstract 06766
# 1054 data/pubmed19n1054.xml.gz: recs 15418, eng 14972, no abstract 02334
# 1055 data/pubmed19n1055.xml.gz: recs 30000, eng 28723, no abstract 04046
# 1056 data/pubmed19n1056.xml.gz: recs 30000, eng 28495, no abstract 02188
# 1057 data/pubmed19n1057.xml.gz: recs 09600, eng 09524, no abstract 05265
# 1058 data/pubmed19n1058.xml.gz: recs 01863, eng 01860, no abstract 00126
# 1059 data/pubmed19n1059.xml.gz: recs 11625, eng 11413, no abstract 01093
# 1060 data/pubmed19n1060.xml.gz: recs 24026, eng 23410, no abstract 01800
# 1061 data/pubmed19n1061.xml.gz: recs 25101, eng 24920, no abstract 02651
# 1062 data/pubmed19n1062.xml.gz: recs 14623, eng 14341, no abstract 03445
# 1063 data/pubmed19n1063.xml.gz: recs 30000, eng 26460, no abstract 04977
# 1064 data/pubmed19n1064.xml.gz: recs 30000, eng 29151, no abstract 03238
# 1065 data/pubmed19n1065.xml.gz: recs 04084, eng 04000, no abstract 00454
# 1066 data/pubmed19n1066.xml.gz: recs 15589, eng 15427, no abstract 01071
# 1067 data/pubmed19n1067.xml.gz: recs 02249, eng 02243, no abstract 00122
# 1068 data/pubmed19n1068.xml.gz: recs 20267, eng 19723, no abstract 02059
# 1069 data/pubmed19n1069.xml.gz: recs 30000, eng 28837, no abstract 05456
# 1070 data/pubmed19n1070.xml.gz: recs 30000, eng 29967, no abstract 02928
# 1071 data/pubmed19n1071.xml.gz: recs 30000, eng 29805, no abstract 03169
# 1072 data/pubmed19n1072.xml.gz: recs 20364, eng 20152, no abstract 01828
# 1073 data/pubmed19n1073.xml.gz: recs 23256, eng 22440, no abstract 02390
# 1074 data/pubmed19n1074.xml.gz: recs 22082, eng 21620, no abstract 02099
# 1075 data/pubmed19n1075.xml.gz: recs 28162, eng 25882, no abstract 03128
# 1076 data/pubmed19n1076.xml.gz: recs 15092, eng 14925, no abstract 01380
# 1077 data/pubmed19n1077.xml.gz: recs 06359, eng 06349, no abstract 00339
# 1078 data/pubmed19n1078.xml.gz: recs 15491, eng 15188, no abstract 01533
# 1079 data/pubmed19n1079.xml.gz: recs 26034, eng 25558, no abstract 02663
# 1080 data/pubmed19n1080.xml.gz: recs 23258, eng 22767, no abstract 02275
# 1081 data/pubmed19n1081.xml.gz: recs 17537, eng 17128, no abstract 01829
# 1082 data/pubmed19n1082.xml.gz: recs 25865, eng 25205, no abstract 02545
# 1083 data/pubmed19n1083.xml.gz: recs 13586, eng 13386, no abstract 01450
# 1084 data/pubmed19n1084.xml.gz: recs 05679, eng 05621, no abstract 00194
# 1085 data/pubmed19n1085.xml.gz: recs 13795, eng 13661, no abstract 01497
# 1086 data/pubmed19n1086.xml.gz: recs 23536, eng 23302, no abstract 02545
# 1087 data/pubmed19n1087.xml.gz: recs 17087, eng 16831, no abstract 02259
# 1088 data/pubmed19n1088.xml.gz: recs 15077, eng 14440, no abstract 01941
# 1089 data/pubmed19n1089.xml.gz: recs 22307, eng 21906, no abstract 02919
# 1090 data/pubmed19n1090.xml.gz: recs 14599, eng 14316, no abstract 02428
# 1091 data/pubmed19n1091.xml.gz: recs 01495, eng 01467, no abstract 00073
# 1092 data/pubmed19n1092.xml.gz: recs 14808, eng 14684, no abstract 01833
# 1093 data/pubmed19n1093.xml.gz: recs 30000, eng 28619, no abstract 02986
# 1094 data/pubmed19n1094.xml.gz: recs 23854, eng 23074, no abstract 02368
# 1095 data/pubmed19n1095.xml.gz: recs 17911, eng 15903, no abstract 02237
# 1096 data/pubmed19n1096.xml.gz: recs 25440, eng 24357, no abstract 03018
# 1097 data/pubmed19n1097.xml.gz: recs 21216, eng 19944, no abstract 03626
# 1098 data/pubmed19n1098.xml.gz: recs 21922, eng 15575, no abstract 01920
# 1099 data/pubmed19n1099.xml.gz: recs 01988, eng 01984, no abstract 00160
# 1100 data/pubmed19n1100.xml.gz: recs 14535, eng 14292, no abstract 01932
# 1101 data/pubmed19n1101.xml.gz: recs 22440, eng 21801, no abstract 03290
# 1102 data/pubmed19n1102.xml.gz: recs 14535, eng 14096, no abstract 01379
# 1103 data/pubmed19n1103.xml.gz: recs 14610, eng 14248, no abstract 01750
# 1104 data/pubmed19n1104.xml.gz: recs 30000, eng 29474, no abstract 02386
# 1105 data/pubmed19n1105.xml.gz: recs 30000, eng 29812, no abstract 01743
# 1106 data/pubmed19n1106.xml.gz: recs 05884, eng 05798, no abstract 00679
# 1107 data/pubmed19n1107.xml.gz: recs 10990, eng 10501, no abstract 02240
# 1108 data/pubmed19n1108.xml.gz: recs 02672, eng 02672, no abstract 00224
# 1109 data/pubmed19n1109.xml.gz: recs 26781, eng 26372, no abstract 02983
# 1110 data/pubmed19n1110.xml.gz: recs 28599, eng 27688, no abstract 03997
# 1111 data/pubmed19n1111.xml.gz: recs 18935, eng 18648, no abstract 01789
# 1112 data/pubmed19n1112.xml.gz: recs 22746, eng 22079, no abstract 02517
# 1113 data/pubmed19n1113.xml.gz: recs 17332, eng 16785, no abstract 02035
# 1114 data/pubmed19n1114.xml.gz: recs 17421, eng 16970, no abstract 01489
# 1115 data/pubmed19n1115.xml.gz: recs 05069, eng 05054, no abstract 00293
# 1116 data/pubmed19n1116.xml.gz: recs 15679, eng 15391, no abstract 01976
# 1117 data/pubmed19n1117.xml.gz: recs 26705, eng 25855, no abstract 02368
# 1118 data/pubmed19n1118.xml.gz: recs 23161, eng 22725, no abstract 02270
# 1119 data/pubmed19n1119.xml.gz: recs 20706, eng 20227, no abstract 02786
# 1120 data/pubmed19n1120.xml.gz: recs 20264, eng 19899, no abstract 02930
# 1121 data/pubmed19n1121.xml.gz: recs 16907, eng 16428, no abstract 01954
# 1122 data/pubmed19n1122.xml.gz: recs 07206, eng 07112, no abstract 00503
# 1123 data/pubmed19n1123.xml.gz: recs 16682, eng 16381, no abstract 01815
# 1124 data/pubmed19n1124.xml.gz: recs 29382, eng 28777, no abstract 03028
# 1125 data/pubmed19n1125.xml.gz: recs 24220, eng 23789, no abstract 02693
# 1126 data/pubmed19n1126.xml.gz: recs 16570, eng 16223, no abstract 02220
# 1127 data/pubmed19n1127.xml.gz: recs 21120, eng 20672, no abstract 03514
# 1128 data/pubmed19n1128.xml.gz: recs 13805, eng 13591, no abstract 01928
# 1129 data/pubmed19n1129.xml.gz: recs 06536, eng 06536, no abstract 00587
# 1130 data/pubmed19n1130.xml.gz: recs 15104, eng 14846, no abstract 01950
# 1131 data/pubmed19n1131.xml.gz: recs 26362, eng 25695, no abstract 03747
# 1132 data/pubmed19n1132.xml.gz: recs 19486, eng 19139, no abstract 02085
# 1133 data/pubmed19n1133.xml.gz: recs 17217, eng 16838, no abstract 02405
# 1134 data/pubmed19n1134.xml.gz: recs 23444, eng 23177, no abstract 03520
# 1135 data/pubmed19n1135.xml.gz: recs 12809, eng 12569, no abstract 01316
# 1136 data/pubmed19n1136.xml.gz: recs 06701, eng 06700, no abstract 00727
# 1137 data/pubmed19n1137.xml.gz: recs 17988, eng 17830, no abstract 02556
# 1138 data/pubmed19n1138.xml.gz: recs 30000, eng 28583, no abstract 03121
# 1139 data/pubmed19n1139.xml.gz: recs 08196, eng 07898, no abstract 00664
# 1140 data/pubmed19n1140.xml.gz: recs 20782, eng 20360, no abstract 02847
# 1141 data/pubmed19n1141.xml.gz: recs 30000, eng 30000, no abstract 10511
# 1142 data/pubmed19n1142.xml.gz: recs 30000, eng 30000, no abstract 10208
# 1143 data/pubmed19n1143.xml.gz: recs 30000, eng 30000, no abstract 09197
# 1144 data/pubmed19n1144.xml.gz: recs 30000, eng 30000, no abstract 15938
# 1145 data/pubmed19n1145.xml.gz: recs 30000, eng 30000, no abstract 10652
# 1146 data/pubmed19n1146.xml.gz: recs 30000, eng 30000, no abstract 09667
# 1147 data/pubmed19n1147.xml.gz: recs 30000, eng 30000, no abstract 09326
# 1148 data/pubmed19n1148.xml.gz: recs 30000, eng 29987, no abstract 14846
# 1149 data/pubmed19n1149.xml.gz: recs 30000, eng 29989, no abstract 25159
# 1150 data/pubmed19n1150.xml.gz: recs 30000, eng 29996, no abstract 29422
# 1151 data/pubmed19n1151.xml.gz: recs 30000, eng 29292, no abstract 13941
# 1152 data/pubmed19n1152.xml.gz: recs 01637, eng 01627, no abstract 00257
# 1153 data/pubmed19n1153.xml.gz: recs 30000, eng 29999, no abstract 12087
# 1154 data/pubmed19n1154.xml.gz: recs 30000, eng 29989, no abstract 14715
# 1155 data/pubmed19n1155.xml.gz: recs 23234, eng 22894, no abstract 06234
# 1156 data/pubmed19n1156.xml.gz: recs 14599, eng 13976, no abstract 01629
# 1157 data/pubmed19n1157.xml.gz: recs 05062, eng 05040, no abstract 00338
# 1158 data/pubmed19n1158.xml.gz: recs 15141, eng 14604, no abstract 02006
# 1159 data/pubmed19n1159.xml.gz: recs 27462, eng 26728, no abstract 04690
# 1160 data/pubmed19n1160.xml.gz: recs 30000, eng 29995, no abstract 00524
# 1161 data/pubmed19n1161.xml.gz: recs 30000, eng 29989, no abstract 00991
# 1162 data/pubmed19n1162.xml.gz: recs 30000, eng 29389, no abstract 02314
# 1163 data/pubmed19n1163.xml.gz: recs 08050, eng 07873, no abstract 00700
# 1164 data/pubmed19n1164.xml.gz: recs 30000, eng 30000, no abstract 00410
# 1165 data/pubmed19n1165.xml.gz: recs 30000, eng 29636, no abstract 02034
# 1166 data/pubmed19n1166.xml.gz: recs 08343, eng 08084, no abstract 00978
# 1167 data/pubmed19n1167.xml.gz: recs 30000, eng 30000, no abstract 08981
# 1168 data/pubmed19n1168.xml.gz: recs 30000, eng 29381, no abstract 03998
# 1169 data/pubmed19n1169.xml.gz: recs 07538, eng 07434, no abstract 00702
# 1170 data/pubmed19n1170.xml.gz: recs 30000, eng 30000, no abstract 03645
# 1171 data/pubmed19n1171.xml.gz: recs 30000, eng 29168, no abstract 05119
# 1172 data/pubmed19n1172.xml.gz: recs 03217, eng 03161, no abstract 00401
# 1173 data/pubmed19n1173.xml.gz: recs 30000, eng 29996, no abstract 20655
# 1174 data/pubmed19n1174.xml.gz: recs 30000, eng 29997, no abstract 08738
# 1175 data/pubmed19n1175.xml.gz: recs 18996, eng 18891, no abstract 02621
# 1176 data/pubmed19n1176.xml.gz: recs 30000, eng 30000, no abstract 04916
# 1177 data/pubmed19n1177.xml.gz: recs 30000, eng 30000, no abstract 05260
# 1178 data/pubmed19n1178.xml.gz: recs 30000, eng 30000, no abstract 05115
# 1179 data/pubmed19n1179.xml.gz: recs 30000, eng 30000, no abstract 04711
# 1180 data/pubmed19n1180.xml.gz: recs 14549, eng 14289, no abstract 01570
# 1181 data/pubmed19n1181.xml.gz: recs 30000, eng 30000, no abstract 14141
# 1182 data/pubmed19n1182.xml.gz: recs 30000, eng 29989, no abstract 10251
# 1183 data/pubmed19n1183.xml.gz: recs 30000, eng 29971, no abstract 14050
# 1184 data/pubmed19n1184.xml.gz: recs 30000, eng 29643, no abstract 08064
# 1185 data/pubmed19n1185.xml.gz: recs 06561, eng 06433, no abstract 00693
# 1186 data/pubmed19n1186.xml.gz: recs 30000, eng 29970, no abstract 09137
# 1187 data/pubmed19n1187.xml.gz: recs 30000, eng 29998, no abstract 14702
# 1188 data/pubmed19n1188.xml.gz: recs 30000, eng 29816, no abstract 17378
# 1189 data/pubmed19n1189.xml.gz: recs 13500, eng 13061, no abstract 01510
# 1190 data/pubmed19n1190.xml.gz: recs 30000, eng 29918, no abstract 09441
# 1191 data/pubmed19n1191.xml.gz: recs 30000, eng 29961, no abstract 06723
# 1192 data/pubmed19n1192.xml.gz: recs 30000, eng 29998, no abstract 01817
# 1193 data/pubmed19n1193.xml.gz: recs 24790, eng 23801, no abstract 03290
# 1194 data/pubmed19n1194.xml.gz: recs 30000, eng 27188, no abstract 07875
# 1195 data/pubmed19n1195.xml.gz: recs 30000, eng 29053, no abstract 04691
# 1196 data/pubmed19n1196.xml.gz: recs 10540, eng 10305, no abstract 01072
# 1197 data/pubmed19n1197.xml.gz: recs 17413, eng 15480, no abstract 02577
# 1198 data/pubmed19n1198.xml.gz: recs 04936, eng 04612, no abstract 00296
# 1199 data/pubmed19n1199.xml.gz: recs 16847, eng 16588, no abstract 02354
# 1200 data/pubmed19n1200.xml.gz: recs 26508, eng 25751, no abstract 03731
# 1201 data/pubmed19n1201.xml.gz: recs 22277, eng 21851, no abstract 02625
# 1202 data/pubmed19n1202.xml.gz: recs 19707, eng 19189, no abstract 02949
# 1203 data/pubmed19n1203.xml.gz: recs 23060, eng 22472, no abstract 02850
# 1204 data/pubmed19n1204.xml.gz: recs 13874, eng 13690, no abstract 01801
# 1205 data/pubmed19n1205.xml.gz: recs 02848, eng 02845, no abstract 00442
# 1206 data/pubmed19n1206.xml.gz: recs 11972, eng 11829, no abstract 01083
# Grand total of 28,966,514 English recs (no abstract 7,902,427) out of 33,735,786 pubmed recs
# Saving MeSh records (29130)
#    29019184 pubmed-abstracts.csv
#       29131 pubmed-mesh.csv
#    29048315 total
# CPU times: user 2h 13min 56s, sys: 46.6 s, total: 2h 14min 43s
# Wall time: 2h 14min 57s

# %% [markdown]
# ## Extract just text
#
# To make the feeding of the LM faster, let's extract just text, combining f"{title}\n{abstract}". We won't do it from scratch but use the already extracted multi-column csv file.

# %%
fn_in  = dest/"pubmed-abstracts.csv.gz"
fn_out = dest/"pubmed-texts.csv.gz"

convert2text = 1 # set to 1 if you want to run the conversion - it does it in chunks so under 10GB RAM or lower the chunksize
if convert2text: 
    chunksize = 1000000 # 1M records chunk
    
    cols_to_keep = [1,2] # title + abstract
    #cols_names = ['title', 'abstract']
    df_iter = pd.read_csv(fn_in, compression='gzip', chunksize=chunksize, keep_default_na=False, usecols=cols_to_keep)
    
    with gzip.open(fn_out, "wt") as f:
        c = 0
        for df in df_iter:        
            #df.head(2)
            c += chunksize
            df['texts'] = df[['title', 'abstract']].apply(lambda x: '\n'.join(x), axis=1)
            df.drop(columns=['title', 'abstract'], inplace=True)
            df.to_csv(f, index=False)
            print(c)
            #df.head(2)
            #break
# Out:
# 1000000
# 2000000
# 3000000
# 4000000
# 5000000
# 6000000
# 7000000
# 8000000
# 9000000
# 10000000
# 11000000
# 12000000
# 13000000
# 14000000
# 15000000
# 16000000
# 17000000
# 18000000
# 19000000
# 20000000
# 21000000
# 22000000
# 23000000
# 24000000
# 25000000
# 26000000
# 27000000
# 28000000
# 29000000
